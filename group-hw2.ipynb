# %% [markdown]
# ## Connect to your workspace

# %%
import os
import azureml.core
from azureml.core import Workspace, Experiment, Datastore
from azureml.widgets import RunDetails

from azureml.core import Dataset

from azureml.pipeline.core import Pipeline, PipelineData, PipelineRun, StepRun, PortDataReference
from azureml.pipeline.steps import PythonScriptStep

from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

from azureml.core.runconfig import RunConfiguration
from azureml.core.conda_dependencies import CondaDependencies

from azureml.core.model import Model

import warnings
warnings.filterwarnings('ignore')

print('SDK Version:', azureml.core.VERSION)
# Out:
# SDK Version: 1.35.0

# %%
ws = Workspace.create(name='MLOP_14',
               subscription_id='6d705e60-c254-4179-9abe-b484e8ac71ef',
               resource_group='MLOP',
               create_resource_group=False,
               location='eastus'
               )
# Out:
# Deploying StorageAccount with name mlop14storagecbc4ef8e3a6.
# Deploying KeyVault with name mlop14keyvault0628dbb87c.
# Deploying AppInsights with name mlop14insightsa90a58820c.
# Deployed AppInsights with name mlop14insightsa90a58820c. Took 1.86 seconds.
# Deploying Workspace with name MLOP_14.
# Deployed StorageAccount with name mlop14storagecbc4ef8e3a6. Took 22.19 seconds.
# Deployed KeyVault with name mlop14keyvault0628dbb87c. Took 20.98 seconds.
# Deployed Workspace with name MLOP_14. Took 64.46 seconds.

# %% [markdown]
# ## Prepare data

# %%
# Get the default datastore
default_ds = ws.get_default_datastore()

# Enumerate all datastores, indicating which is the default
for ds_name in ws.datastores:
    print(ds_name, "- Default =", ds_name == default_ds.name)
# Out:
# workspacefilestore - Default = False
# workspaceblobstore - Default = True
# workspaceartifactstore - Default = False
# workspaceworkingdirectory - Default = False

# %%
if 'telecom dataset' not in ws.datasets:
    default_ds.upload_files(files=['/Users/lingyizhao/Desktop/mlop/project/clean_data.csv'], # Upload the diabetes csv files in /data
                        target_path='telecom-data/', # Put it in a folder path in the datastore
                        overwrite=True, # Replace existing files of the same name
                        show_progress=True)

    #Create a tabular dataset from the path on the datastore (this may take a short while)
    tab_data_set = Dataset.Tabular.from_delimited_files(path=(default_ds, 'telecom-data/clean_data.csv'))

    # Register the tabular dataset
    try:
        tab_data_set = tab_data_set.register(workspace=ws, 
                                name='telecom dataset',
                                description='telecom data',
                                tags = {'format':'CSV'},
                                create_new_version=True)
        print('Dataset registered.')
    except Exception as ex:
        print(ex)
else:
    print('Dataset already registered.')
# Out:
# Uploading an estimated of 1 files
# Uploading /Users/lingyizhao/Desktop/mlop/project/clean_data.csv
# Uploaded /Users/lingyizhao/Desktop/mlop/project/clean_data.csv, 1 files out of an estimated total of 1
# Uploaded 1 files
# Dataset registered.

# %%
# Display dataframe
tab_data_set.to_pandas_dataframe()
# Out:
#      state  account_length  area_code phone_number intl_plan voice_mail_plan  \
# 0       KS             128        415     382-4657        no             yes
# 1       OH             107        415     371-7191        no             yes
# 2       NJ             137        415     358-1921        no              no
# 3       OH              84        408     375-9999       yes              no
# 4       OK              75        415     330-6626       yes              no
# ...    ...             ...        ...          ...       ...             ...
# 4995    HI              50        408     365-8751        no             yes
# 4996    WV             152        415     334-9736        no              no
# 4997    DC              61        415     333-6861        no              no
# 4998    DC             109        510     394-2206        no              no
# 4999    VT              86        415     373-8058        no             yes
#
#       number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                        25              265.1              110
# 1                        26              161.6              123
# 2                         0              243.4              114
# 3                         0              299.4               71
# 4                         0              166.7              113
# ...                     ...                ...              ...
# 4995                     40              235.7              127
# 4996                      0              184.2               90
# 4997                      0              140.6               89
# 4998                      0              188.8               67
# 4999                     34              129.4              102
#
#       total_day_charge  ...  total_eve_calls  total_eve_charge  \
# 0                45.07  ...               99             16.78
# 1                27.47  ...              103             16.62
# 2                41.38  ...              110             10.30
# 3                50.90  ...               88              5.26
# 4                28.34  ...              122             12.61
# ...                ...  ...              ...               ...
# 4995             40.07  ...              126             18.96
# 4996             31.31  ...               73             21.83
# 4997             23.90  ...              128             14.69
# 4998             32.10  ...               92             14.59
# 4999             22.00  ...              104             22.70
#
#       total_night_minutes  total_night_calls  total_night_charge  \
# 0                   244.7                 91               11.01
# 1                   254.4                103               11.45
# 2                   162.6                104                7.32
# 3                   196.9                 89                8.86
# 4                   186.9                121                8.41
# ...                   ...                ...                 ...
# 4995                297.5                116               13.39
# 4996                213.6                113                9.61
# 4997                212.4                 97                9.56
# 4998                224.4                 89               10.10
# 4999                154.8                100                6.97
#
#       total_intl_minutes  total_intl_calls  total_intl_charge  \
# 0                   10.0                 3               2.70
# 1                   13.7                 3               3.70
# 2                   12.2                 5               3.29
# 3                    6.6                 7               1.78
# 4                   10.1                 3               2.73
# ...                  ...               ...                ...
# 4995                 9.9                 5               2.67
# 4996                14.7                 2               3.97
# 4997                13.6                 4               3.67
# 4998                 8.5                 6               2.30
# 4999                 9.3                16               2.51
#
#       number_customer_service_calls  churned
# 0                                 1   False.
# 1                                 1   False.
# 2                                 0   False.
# 3                                 2   False.
# 4                                 3   False.
# ...                             ...      ...
# 4995                              2   False.
# 4996                              3    True.
# 4997                              1   False.
# 4998                              0   False.
# 4999                              0   False.
#
# [5000 rows x 21 columns]

# %%
#tab_data_set.to_pandas_dataframe().isnull().sum()

# %%
# df = tab_data_set.to_pandas_dataframe().dropna()
# # df1 = df[df.isna().any(axis=1)]
# # df1
# df.isnull().sum()

# %% [markdown]
# ## Create scripts for pipeline steps

# %%
import os
# Create a folder for the pipeline step files
experiment_folder = 'telecom_pipeline'
os.makedirs(experiment_folder, exist_ok=True)

print(experiment_folder)
# Out:
# telecom_pipeline

# %% [markdown]
# ### Data Preprocessing

# %%
# %%writefile $experiment_folder/prep_telecom.py
# Import libraries
import os
import argparse
import pandas as pd
from azureml.core import Run
from sklearn.preprocessing import MinMaxScaler

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument("--input-data", type=str, dest='raw_dataset_id', help='raw dataset')
parser.add_argument('--prepped-data', type=str, dest='prepped_data', default='prepped_data', help='Folder for results')
args = parser.parse_args()
save_folder = args.prepped_data

# Get the experiment run context
run = Run.get_context()

# load the data (passed as an input dataset)
print("Loading Data...")
telecom = run.input_datasets['raw_data'].to_pandas_dataframe()

# Log raw row count
row_count = (len(telecom))
run.log('raw_rows', row_count)

# data cleaning
telecom = telecom.dropna()

telecom['voice_mail_plan'] = telecom['voice_mail_plan'].map(lambda x: x.strip())
telecom['intl_plan'] = telecom['intl_plan'].map(lambda x: x.strip())
telecom['churned'] = telecom['churned'].astype('str') 
telecom['churned'] = telecom['churned'].map(lambda x: x.strip())
telecom = telecom.replace(['True.', 'False.'], ['True','False']) 

# telecom = telecom[telecom.account_length != 99999]
# telecom = telecom[telecom.account_length != -1]
# telecom = telecom[telecom.area_code != 99999]
# telecom  = telecom[telecom.area_code != -20]
# telecom = telecom[telecom.area_code != 1]
# telecom = telecom[telecom.total_day_charge < 2000]
# telecom = telecom[telecom.churned != 'nan']
# telecom = telecom.replace(['T', 'F', 'TRUE', 'FALSE', 'True.', 'False.'], 
#                      ['True','False', 'True','False','True','False'])

# Log processed rows
row_count = (len(telecom))
run.log('processed_rows', row_count)

# Save the prepped data
print("Saving Data...")
os.makedirs(save_folder, exist_ok=True)
save_path = os.path.join(save_folder,'data.csv')
telecom.to_csv(save_path, index=False, header=True)

# End the run
run.complete()
# Out:
# Overwriting telecom_pipeline/prep_telecom.py

# %%
# %%writefile $experiment_folder/train_telecom.py
# Import libraries
from azureml.core import Run, Model
import argparse
import pandas as pd
import numpy as np
import joblib
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument("--training-folder", type=str, dest='training_folder', help='training data folder')
args = parser.parse_args()
training_folder = args.training_folder

# Get the experiment run context
run = Run.get_context()

# load the prepared data file in the training folder
print("Loading Data...")
file_path = os.path.join(training_folder,'data.csv')
telecom = pd.read_csv(file_path)

# Separate features and labels
y = np.where(telecom['churned'] == 'True',1,0)
## Drop some useless columns
to_drop = ['state','area_code','phone_number','churned']
churn_feat_space = telecom.drop(to_drop, axis=1)
## converted yes and no
yes_no_cols = ["intl_plan","voice_mail_plan"]
churn_feat_space[yes_no_cols] = churn_feat_space[yes_no_cols] == 'yes'
X = churn_feat_space


# Split data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)

# Scale the data, using standardization
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)


# Train the random forest model
print('Training a random forest model...')
model = RandomForestClassifier().fit(X_train, y_train)

# calculate accuracy
y_hat = model.predict(X_test)
acc = np.average(y_hat == y_test)
print('Accuracy:', acc)
run.log('Accuracy', np.float(acc))

# calculate AUC
y_scores = model.predict_proba(X_test)
auc = roc_auc_score(y_test,y_scores[:,1])
print('AUC: ' + str(auc))
run.log('AUC', np.float(auc))

# plot ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_scores[:,1])
fig = plt.figure(figsize=(6, 4))
# Plot the diagonal 50% line
plt.plot([0, 1], [0, 1], 'k--')
# Plot the FPR and TPR achieved by our model
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
run.log_image(name = "ROC", plot = fig)
plt.show()


# from sklearn.metrics import confusion_matrix
# from sklearn.metrics import classification_report
# from sklearn.metrics import precision_score
# from sklearn.metrics import recall_score

# # calculate accuracy, precision and recall
# def cal_evaluation(classifier, cm):
#     tn = cm[0][0]
#     fp = cm[0][1]
#     fn = cm[1][0]
#     tp = cm[1][1]
#     accuracy  = (tp + tn) / (tp + fp + fn + tn + 0.0)
#     precision = tp / (tp + fp + 0.0)
#     recall = tp / (tp + fn + 0.0)
#     print (classifier)
#     print ("Accuracy is: %0.3f" % accuracy)
#     print ("precision is: %0.3f" % precision)
#     print ("recall is: %0.3f" % recall)

# # print out confusion matrices
# def draw_confusion_matrices(confusion_matricies):
#     class_names = ['Not','Churn']
#     for cm in confusion_matrices:
#         classifier, cm = cm[0], cm[1]
#         cal_evaluation(classifier, cm)
#         fig = plt.figure()
#         ax = fig.add_subplot(111)
#         cax = ax.matshow(cm, interpolation='nearest',cmap=plt.get_cmap('Reds'))
#         plt.title('Confusion matrix for %s' % classifier)
#         fig.colorbar(cax)
#         ax.set_xticklabels([''] + class_names)
#         ax.set_yticklabels([''] + class_names)
#         plt.xlabel('Predicted')
#         plt.ylabel('True')
#         run.log_image(name = "confusion_matrices", plot = fig)
#         plt.show()
        
# confusion_matrices = [("Random Forest", confusion_matrix(y_test,model.predict(X_test)))]

# draw_confusion_matrices(confusion_matrices)


# Save the trained model in the outputs folder
print("Saving model...")
os.makedirs('outputs', exist_ok=True)
model_file = os.path.join('outputs', 'randomforest_model.pkl')
joblib.dump(value=model, filename=model_file)

# Register the model
print('Registering model...')
Model.register(workspace=run.experiment.workspace,
               model_path = model_file,
               model_name = 'randomforest_model',
               tags={'Training context':'Pipeline'},
               properties={'AUC': np.float(auc), 'Accuracy': np.float(acc)})


run.complete()
# Out:
# Overwriting telecom_pipeline/train_telecom.py

# %% [markdown]
# ## Prepare a compute environment for the pipeline steps

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "mlop-test"

try:
    # Check for existing compute target
    pipeline_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # If it doesn't already exist, create it
    try:
        compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS11_V2', max_nodes=2)
        pipeline_cluster = ComputeTarget.create(ws, cluster_name, compute_config)
        pipeline_cluster.wait_for_completion(show_output=True)
    except Exception as ex:
        print(ex)
# Out:
# InProgress....
# SucceededProvisioning operation finished, operation "Succeeded"
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %%
from azureml.core import Environment
from azureml.core.conda_dependencies import CondaDependencies
from azureml.core.runconfig import RunConfiguration

# Create a Python environment for the experiment
telecom_env = Environment("telecom-pipeline-env")

# Create a set of package dependencies
telecom_packages = CondaDependencies.create(conda_packages=['scikit-learn','ipykernel','matplotlib','pandas','pip'],
                                             pip_packages=['azureml-defaults','azureml-dataprep[pandas]','pyarrow'])

# Add the dependencies to the environment
telecom_env.python.conda_dependencies = telecom_packages

# Register the environment 
telecom_env.register(workspace=ws)
registered_env = Environment.get(ws, 'telecom-pipeline-env')

# Create a new runconfig object for the pipeline
pipeline_run_config = RunConfiguration()

# Use the compute you created above. 
pipeline_run_config.target = pipeline_cluster

# Assign the environment to the run configuration
pipeline_run_config.environment = registered_env

print ("Run configuration created.")
# Out:
# Run configuration created.

# %% [markdown]
# ## Create and run a pipeline

# %%
from azureml.pipeline.core import PipelineData
from azureml.pipeline.steps import PythonScriptStep

# Get the training dataset
telecom_ds = ws.datasets.get("telecom dataset")

# Create a PipelineData (temporary Data Reference) for the model folder
prepped_data_folder = PipelineData("prepped_data_folder", datastore=ws.get_default_datastore())

# Step 1, Run the data prep script
train_step = PythonScriptStep(name = "Prepare Data",
                                source_directory = experiment_folder,
                                script_name = "prep_telecom.py",
                                arguments = ['--input-data', telecom_ds.as_named_input('raw_data'),
                                             '--prepped-data', prepped_data_folder],
                                outputs=[prepped_data_folder],
                                compute_target = pipeline_cluster,
                                runconfig = pipeline_run_config,
                                allow_reuse = True)

# Step 2, run the training script
register_step = PythonScriptStep(name = "Train and Register Model",
                                source_directory = experiment_folder,
                                script_name = "train_telecom.py",
                                arguments = ['--training-folder', prepped_data_folder],
                                inputs=[prepped_data_folder],
                                compute_target = pipeline_cluster,
                                runconfig = pipeline_run_config,
                                allow_reuse = True)

print("Pipeline steps defined")
# Out:
# Pipeline steps defined

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline
from azureml.widgets import RunDetails

# Construct the pipeline
pipeline_steps = [train_step, register_step]
pipeline = Pipeline(workspace=ws, steps=pipeline_steps)
print("Pipeline is built.")

# Create an experiment and run the pipeline
experiment = Experiment(workspace=ws, name = 'telecom-pipeline')
pipeline_run = experiment.submit(pipeline, regenerate_outputs=True)
print("Pipeline submitted for execution.")
RunDetails(pipeline_run).show()
pipeline_run.wait_for_completion(show_output=True)
# Out:
# Pipeline is built.
# Created step Prepare Data [93becb17][9f491d08-cebc-4ea7-9e3a-d0765cb3e897], (This step will run and generate new outputs)
# Created step Train and Register Model [e21083f7][2204e40e-5743-4d95-958d-669f6323d211], (This step will run and generate new outputs)
# Submitted PipelineRun 8530c936-18ef-4aef-8dd9-298666786f4d
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/8530c936-18ef-4aef-8dd9-298666786f4d?wsid=/subscriptions/6d705e60-c254-4179-9abe-b484e8ac71ef/resourcegroups/MLOP/workspaces/MLOP_14&tid=83b02c92-5f26-48ed-9e5b-6c2fca46a8e6
# Pipeline submitted for execution.
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
# PipelineRunId: 8530c936-18ef-4aef-8dd9-298666786f4d
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/8530c936-18ef-4aef-8dd9-298666786f4d?wsid=/subscriptions/6d705e60-c254-4179-9abe-b484e8ac71ef/resourcegroups/MLOP/workspaces/MLOP_14&tid=83b02c92-5f26-48ed-9e5b-6c2fca46a8e6
# PipelineRun Status: Running
#
#
# StepRunId: afbedb46-4924-4cbe-abec-b867b68805e4
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/afbedb46-4924-4cbe-abec-b867b68805e4?wsid=/subscriptions/6d705e60-c254-4179-9abe-b484e8ac71ef/resourcegroups/MLOP/workspaces/MLOP_14&tid=83b02c92-5f26-48ed-9e5b-6c2fca46a8e6
# StepRun( Prepare Data ) Status: Running
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2021/11/02 22:54:38 Downloading source code...
# 2021/11/02 22:54:39 Finished downloading source code
# 2021/11/02 22:54:40 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/11/02 22:54:40 Successfully set up Docker network: acb_default_network
# 2021/11/02 22:54:40 Setting up Docker configuration...
# 2021/11/02 22:54:40 Successfully set up Docker configuration
# 2021/11/02 22:54:40 Logging in to registry: fd2bda387b2344cc8ecc8368b45be706.azurecr.io
# 2021/11/02 22:54:41 Successfully logged into fd2bda387b2344cc8ecc8368b45be706.azurecr.io
# 2021/11/02 22:54:41 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/11/02 22:54:41 Scanning for dependencies...
# 2021/11/02 22:54:42 Successfully scanned dependencies
# 2021/11/02 22:54:42 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
# Step 1/19 : FROM mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210922.v1@sha256:bfed4edd2085c7fa221827c7ea4d1dc8c48fd52d64b9411260bf94f7f6fae31a
# mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210922.v1@sha256:bfed4edd2085c7fa221827c7ea4d1dc8c48fd52d64b9411260bf94f7f6fae31a: Pulling from azureml/openmpi3.1.2-ubuntu18.04
# e4ca327ec0e7: Already exists
# f0fb8b64b41b: Pulling fs layer
# e43ee38068bf: Pulling fs layer
# 409df78264bc: Pulling fs layer
# a2eb44ae9dc0: Pulling fs layer
# b8ff7afa1c52: Pulling fs layer
# d92dd21f7e9a: Pulling fs layer
# 965946e36f3d: Pulling fs layer
# 9d3ce4a2dac8: Pulling fs layer
# a2eb44ae9dc0: Waiting
# b8ff7afa1c52: Waiting
# d92dd21f7e9a: Waiting
# 965946e36f3d: Waiting
# 9d3ce4a2dac8: Waiting
# 409df78264bc: Verifying Checksum
# 409df78264bc: Download complete
# e43ee38068bf: Verifying Checksum
# e43ee38068bf: Download complete
# b8ff7afa1c52: Verifying Checksum
# b8ff7afa1c52: Download complete
# d92dd21f7e9a: Verifying Checksum
# d92dd21f7e9a: Download complete
# a2eb44ae9dc0: Download complete
# 9d3ce4a2dac8: Download complete
# 965946e36f3d: Verifying Checksum
# 965946e36f3d: Download complete
# f0fb8b64b41b: Verifying Checksum
# f0fb8b64b41b: Download complete
# f0fb8b64b41b: Pull complete
# e43ee38068bf: Pull complete
# 409df78264bc: Pull complete
# a2eb44ae9dc0: Pull complete
# b8ff7afa1c52: Pull complete
# d92dd21f7e9a: Pull complete
# 965946e36f3d: Pull complete
# 9d3ce4a2dac8: Pull complete
# Digest: sha256:bfed4edd2085c7fa221827c7ea4d1dc8c48fd52d64b9411260bf94f7f6fae31a
# Status: Downloaded newer image for mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210922.v1@sha256:bfed4edd2085c7fa221827c7ea4d1dc8c48fd52d64b9411260bf94f7f6fae31a
#  ---> 9e882d6546b4
# Step 2/19 : USER root
#  ---> Running in be30dbb8f4d7
# Removing intermediate container be30dbb8f4d7
#  ---> dc2bb73c0a7c
# Step 3/19 : RUN mkdir -p $HOME/.cache
#  ---> Running in a8be1414ae71
# Removing intermediate container a8be1414ae71
#  ---> edb7aee47f63
# Step 4/19 : WORKDIR /
#  ---> Running in 822e36744c56
# Removing intermediate container 822e36744c56
#  ---> c21b997ec916
# Step 5/19 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 50ceacbe92a9
# Step 6/19 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in bec046c27748
# Removing intermediate container bec046c27748
#  ---> 0032d14f76af
# Step 7/19 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 812d2e93735d
# Step 8/19 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472 -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 5fdfdbf58f4f
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working...
# done
#
# Downloading and Extracting Packages
#
# freetype-2.10.4      | 901 KB    |            |   0%
# freetype-2.10.4      | 901 KB    | ########## | 100%
# freetype-2.10.4      | 901 KB    | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# pyparsing-2.4.7      | 64 KB     |            |   0%
# pyparsing-2.4.7      | 64 KB     | ########## | 100%
#
# parso-0.7.0          | 71 KB     |            |   0%
# parso-0.7.0          | 71 KB     | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | ##         |  21%
# python-3.6.2         | 27.0 MB   | #####1     |  52%
# python-3.6.2         | 27.0 MB   | #########6 |  96%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# lcms2-2.11           | 419 KB    |            |   0%
# lcms2-2.11           | 419 KB    | ########## | 100%
#
# openssl-1.0.2u       | 3.1 MB    |            |   0%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
#
# ipykernel-5.3.4      | 176 KB    |            |   0%
# ipykernel-5.3.4      | 176 KB    | ########## | 100%
#
# decorator-4.4.2      | 14 KB     |            |   0%
# decorator-4.4.2      | 14 KB     | ########## | 100%
#
# libstdcxx-ng-9.1.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
#
# readline-7.0         | 387 KB    |            |   0%
# readline-7.0         | 387 KB    | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# libpng-1.6.37        | 364 KB    |            |   0%
# libpng-1.6.37        | 364 KB    | ########## | 100%
#
# libffi-3.2.1         | 52 KB     |            |   0%
# libffi-3.2.1         | 52 KB     | ########## | 100%
#
# backcall-0.2.0       | 14 KB     |            |   0%
# backcall-0.2.0       | 14 KB     | ########## | 100%
#
# pickleshare-0.7.5    | 13 KB     |            |   0%
# pickleshare-0.7.5    | 13 KB     | ########## | 100%
#
# numpy-1.19.1         | 20 KB     |            |   0%
# numpy-1.19.1         | 20 KB     | ########## | 100%
#
# numpy-base-1.19.1    | 5.2 MB    |            |   0%
# numpy-base-1.19.1    | 5.2 MB    | ########## | 100%
# numpy-base-1.19.1    | 5.2 MB    | ########## | 100%
#
# wheel-0.35.1         | 36 KB     |            |   0%
# wheel-0.35.1         | 36 KB     | ########## | 100%
#
# gstreamer-1.14.0     | 3.8 MB    |            |   0%
# gstreamer-1.14.0     | 3.8 MB    | ########## | 100%
# gstreamer-1.14.0     | 3.8 MB    | ########## | 100%
#
# pip-20.2.4           | 2.0 MB    |            |   0%
# pip-20.2.4           | 2.0 MB    | ########## | 100%
# pip-20.2.4           | 2.0 MB    | ########## | 100%
#
# libxml2-2.9.10       | 1.3 MB    |            |   0%
# libxml2-2.9.10       | 1.3 MB    | ########## | 100%
# libxml2-2.9.10       | 1.3 MB    | ########## | 100%
#
# libuuid-1.0.3        | 16 KB     |            |   0%
# libuuid-1.0.3        | 16 KB     | ########## | 100%
#
# threadpoolctl-2.1.0  | 16 KB     |            |   0%
# threadpoolctl-2.1.0  | 16 KB     | ########## | 100%
#
# pyqt-5.9.2           | 5.6 MB    |            |   0%
# pyqt-5.9.2           | 5.6 MB    | ########## | 100%
# pyqt-5.9.2           | 5.6 MB    | ########## | 100%
#
# jpeg-9b              | 247 KB    |            |   0%
# jpeg-9b              | 247 KB    | ########## | 100%
#
# pytz-2020.1          | 239 KB    |            |   0%
# pytz-2020.1          | 239 KB    | ########## | 100%
# pytz-2020.1          | 239 KB    | ########## | 100%
#
# pandas-1.1.3         | 10.5 MB   |            |   0%
# pandas-1.1.3         | 10.5 MB   | ##4        |  25%
# pandas-1.1.3         | 10.5 MB   | ######8    |  69%
# pandas-1.1.3         | 10.5 MB   | #########3 |  93%
# pandas-1.1.3         | 10.5 MB   | ########## | 100%
#
# matplotlib-base-3.3. | 6.7 MB    |            |   0%
# matplotlib-base-3.3. | 6.7 MB    | ########## | 100%
# matplotlib-base-3.3. | 6.7 MB    | ########## | 100%
#
# zstd-1.4.4           | 1006 KB   |            |   0%
# zstd-1.4.4           | 1006 KB   | ########## | 100%
# zstd-1.4.4           | 1006 KB   | ########## | 100%
#
# kiwisolver-1.2.0     | 91 KB     |            |   0%
# kiwisolver-1.2.0     | 91 KB     | ########## | 100%
#
# jupyter_core-4.6.3   | 75 KB     |            |   0%
# jupyter_core-4.6.3   | 75 KB     | ########## | 100%
#
# scikit-learn-0.23.2  | 6.9 MB    |            |   0%
# scikit-learn-0.23.2  | 6.9 MB    | ########## | 100%
# scikit-learn-0.23.2  | 6.9 MB    | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# glib-2.56.2          | 5.0 MB    |            |   0%
# glib-2.56.2          | 5.0 MB    | ########## | 100%
# glib-2.56.2          | 5.0 MB    | ########## | 100%
#
# qt-5.9.6             | 86.7 MB   |            |   0%
# qt-5.9.6             | 86.7 MB   | 7          |   8%
# qt-5.9.6             | 86.7 MB   | ##1        |  21%
# qt-5.9.6             | 86.7 MB   | ###4       |  34%
# qt-5.9.6             | 86.7 MB   | ####5      |  46%
# qt-5.9.6             | 86.7 MB   | #####8     |  59%
# qt-5.9.6             | 86.7 MB   | #######1   |  71%
# qt-5.9.6             | 86.7 MB   | ########5  |  85%
# qt-5.9.6             | 86.7 MB   | #########6 |  97%
#
# qt-5.9.6             | 86.7 MB   | ########## | 100%
#
# xz-5.2.5             | 438 KB    |            |   0%
# xz-5.2.5             | 438 KB    | ########## | 100%
#
# mkl-service-2.3.0    | 208 KB    |            |   0%
# mkl-service-2.3.0    | 208 KB    | ########## | 100%
#
# libtiff-4.1.0        | 607 KB    |            |   0%
# libtiff-4.1.0        | 607 KB    | ########## | 100%
# libtiff-4.1.0        | 607 KB    | ########## | 100%
#
# python-dateutil-2.8. | 224 KB    |            |   0%
# python-dateutil-2.8. | 224 KB    | ########## | 100%
#
# mkl_random-1.1.0     | 369 KB    |            |   0%
# mkl_random-1.1.0     | 369 KB    | ########## | 100%
#
# libgfortran-ng-7.3.0 | 1.3 MB    |            |   0%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
#
# libsodium-1.0.18     | 387 KB    |            |   0%
# libsodium-1.0.18     | 387 KB    | ########## | 100%
# libsodium-1.0.18     | 387 KB    | ########## | 100%
#
# prompt-toolkit-3.0.8 | 244 KB    |            |   0%
# prompt-toolkit-3.0.8 | 244 KB    | ########## | 100%
# prompt-toolkit-3.0.8 | 244 KB    | ########## | 100%
#
# olefile-0.46         | 48 KB     |            |   0%
# olefile-0.46         | 48 KB     | ########## | 100%
#
# mkl_fft-1.2.0        | 164 KB    |            |   0%
# mkl_fft-1.2.0        | 164 KB    | ########## | 100%
#
# libxcb-1.14          | 610 KB    |            |   0%
# libxcb-1.14          | 610 KB    | ########## | 100%
# libxcb-1.14          | 610 KB    | ########## | 100%
#
# cycler-0.10.0        | 13 KB     |            |   0%
# cycler-0.10.0        | 13 KB     | ########## | 100%
#
# fontconfig-2.13.0    | 291 KB    |            |   0%
# fontconfig-2.13.0    | 291 KB    | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# traitlets-4.3.3      | 137 KB    |            |   0%
# traitlets-4.3.3      | 137 KB    | ########## | 100%
# traitlets-4.3.3      | 137 KB    | ########## | 100%
#
# tornado-6.0.4        | 650 KB    |            |   0%
# tornado-6.0.4        | 650 KB    | ########## | 100%
# tornado-6.0.4        | 650 KB    | ########## | 100%
#
# jedi-0.17.2          | 952 KB    |            |   0%
# jedi-0.17.2          | 952 KB    | #########  |  91%
# jedi-0.17.2          | 952 KB    | ########## | 100%
#
# pyzmq-19.0.2         | 479 KB    |            |   0%
# pyzmq-19.0.2         | 479 KB    | ########## | 100%
# pyzmq-19.0.2         | 479 KB    | ########## | 100%
#
# setuptools-50.3.0    | 891 KB    |            |   0%
# setuptools-50.3.0    | 891 KB    | ########## | 100%
# setuptools-50.3.0    | 891 KB    | ########## | 100%
#
# scipy-1.5.2          | 18.5 MB   |            |   0%
# scipy-1.5.2          | 18.5 MB   | ###2       |  33%
# scipy-1.5.2          | 18.5 MB   | ########7  |  87%
# scipy-1.5.2          | 18.5 MB   | ########## | 100%
#
# ptyprocess-0.6.0     | 23 KB     |            |   0%
# ptyprocess-0.6.0     | 23 KB     | ########## | 100%
#
# ipython_genutils-0.2 | 39 KB     |            |   0%
# ipython_genutils-0.2 | 39 KB     | ########## | 100%
#
# lz4-c-1.9.2          | 203 KB    |            |   0%
# lz4-c-1.9.2          | 203 KB    | ########## | 100%
#
# matplotlib-3.3.1     | 24 KB     |            |   0%
# matplotlib-3.3.1     | 24 KB     | ########## | 100%
#
# pexpect-4.8.0        | 84 KB     |            |   0%
# pexpect-4.8.0        | 84 KB     | ########## | 100%
#
# gst-plugins-base-1.1 | 6.3 MB    |            |   0%
# gst-plugins-base-1.1 | 6.3 MB    | ########## | 100%
# gst-plugins-base-1.1 | 6.3 MB    | ########## | 100%
#
# pcre-8.44            | 269 KB    |            |   0%
# pcre-8.44            | 269 KB    | ########## | 100%
#
# dbus-1.13.18         | 586 KB    |            |   0%
# dbus-1.13.18         | 586 KB    | ########## | 100%
# dbus-1.13.18         | 586 KB    | ########## | 100%
#
# libgcc-ng-9.1.0      | 8.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 8.1 MB    | #######9   |  79%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
#
# jupyter_client-6.1.7 | 76 KB     |            |   0%
# jupyter_client-6.1.7 | 76 KB     | ########## | 100%
#
# sip-4.19.24          | 297 KB    |            |   0%
# sip-4.19.24          | 297 KB    | ########## | 100%
#
# tk-8.6.10            | 3.2 MB    |            |   0%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
#
# icu-58.2             | 22.7 MB   |            |   0%
# icu-58.2             | 22.7 MB   | #2         |  13%
# icu-58.2             | 22.7 MB   | ####4      |  44%
# icu-58.2             | 22.7 MB   | #######5   |  76%
# icu-58.2             | 22.7 MB   | ########## | 100%
# icu-58.2             | 22.7 MB   | ########## | 100%
#
# pygments-2.7.1       | 704 KB    |            |   0%
# pygments-2.7.1       | 704 KB    | ########## | 100%
# pygments-2.7.1       | 704 KB    | ########## | 100%
#
# wcwidth-0.2.5        | 37 KB     |            |   0%
# wcwidth-0.2.5        | 37 KB     | ########## | 100%
#
# ncurses-6.0          | 907 KB    |            |   0%
# ncurses-6.0          | 907 KB    | ########## | 100%
# ncurses-6.0          | 907 KB    | ########## | 100%
#
# certifi-2020.6.20    | 160 KB    |            |   0%
# certifi-2020.6.20    | 160 KB    | ########## | 100%
#
# ipython-7.16.1       | 1.1 MB    |            |   0%
# ipython-7.16.1       | 1.1 MB    | ########## | 100%
# ipython-7.16.1       | 1.1 MB    | ########## | 100%
#
# expat-2.2.10         | 192 KB    |            |   0%
# expat-2.2.10         | 192 KB    | ########## | 100%
#
# zeromq-4.3.3         | 678 KB    |            |   0%
# zeromq-4.3.3         | 678 KB    | ########## | 100%
# zeromq-4.3.3         | 678 KB    | ########## | 100%
#
# pillow-8.0.0         | 675 KB    |            |   0%
# pillow-8.0.0         | 675 KB    | ########## | 100%
# pillow-8.0.0         | 675 KB    | ########## | 100%
#
# mkl-2019.4           | 204.1 MB  |            |   0%
# mkl-2019.4           | 204.1 MB  |            |   1%
# mkl-2019.4           | 204.1 MB  | 5          |   5%
# mkl-2019.4           | 204.1 MB  | 8          |   8%
# mkl-2019.4           | 204.1 MB  | #1         |  11%
# mkl-2019.4           | 204.1 MB  | #4         |  14%
# mkl-2019.4           | 204.1 MB  | #6         |  17%
# mkl-2019.4           | 204.1 MB  | #8         |  19%
# mkl-2019.4           | 204.1 MB  | ##1        |  22%
# mkl-2019.4           | 204.1 MB  | ##6        |  26%
# mkl-2019.4           | 204.1 MB  | ###1       |  31%
# mkl-2019.4           | 204.1 MB  | ###7       |  38%
# mkl-2019.4           | 204.1 MB  | ####4      |  44%
# mkl-2019.4           | 204.1 MB  | #####      |  50%
# mkl-2019.4           | 204.1 MB  | #####6     |  56%
# mkl-2019.4           | 204.1 MB  | ######1    |  62%
# mkl-2019.4           | 204.1 MB  | ######7    |  67%
# mkl-2019.4           | 204.1 MB  | #######3   |  73%
# mkl-2019.4           | 204.1 MB  | #######8   |  78%
# mkl-2019.4           | 204.1 MB  | ########5  |  85%
# mkl-2019.4           | 204.1 MB  | #########2 |  93%
# mkl-2019.4           | 204.1 MB  | #########8 |  99%
#
# mkl-2019.4           | 204.1 MB  | ########## | 100%
#
# intel-openmp-2020.2  | 947 KB    |            |   0%
# intel-openmp-2020.2  | 947 KB    | ########## | 100%
# intel-openmp-2020.2  | 947 KB    | ########## | 100%
#
# joblib-0.17.0        | 205 KB    |            |   0%
# joblib-0.17.0        | 205 KB    | ########## | 100%
#
# ca-certificates-2020 | 128 KB    |            |   0%
# ca-certificates-2020 | 128 KB    | ########## | 100%
#
# six-1.15.0           | 13 KB     |            |   0%
# six-1.15.0           | 13 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Installing pip dependencies: ...working...
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.nmiy_ci_.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.35.0-py3-none-any.whl (3.1 kB)
# Collecting azureml-dataprep[pandas]
#   Downloading azureml_dataprep-2.24.0-py3-none-any.whl (39.4 MB)
# Collecting pyarrow
#   Downloading pyarrow-6.0.0-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25.5 MB)
# Collecting opencensus-ext-azure==1.0.8
#   Downloading opencensus_ext_azure-1.0.8-py2.py3-none-any.whl (35 kB)
# Collecting werkzeug<=1.0.1,>=0.16.1
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting azureml-core~=1.35.0
#   Downloading azureml_core-1.35.0.post1-py3-none-any.whl (2.2 MB)
# Collecting gunicorn==20.1.0
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.35.0
#   Downloading azureml_dataset_runtime-1.35.0-py3-none-any.whl (3.5 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting azureml-inference-server-http~=0.3.1
#   Downloading azureml_inference_server_http-0.3.2-py3-none-any.whl (38 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting azure-identity==1.7.0
#   Downloading azure_identity-1.7.0-py2.py3-none-any.whl (129 kB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.21-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting azureml-dataprep-rslex~=2.0.0dev0
#   Downloading azureml_dataprep_rslex-2.0.0-cp36-cp36m-manylinux2010_x86_64.whl (13.1 MB)
# Collecting azureml-dataprep-native<39.0.0,>=38.0.0
#   Downloading azureml_dataprep_native-38.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Requirement already satisfied, skipping upgrade: pandas<2.0.0,>=0.23.4; extra == "pandas" in /azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472/lib/python3.6/site-packages (from azureml-dataprep[pandas]->-r /azureml-environment-setup/condaenv.nmiy_ci_.requirements.txt (line 2)) (1.1.3)
# Requirement already satisfied, skipping upgrade: numpy<2.0.0,>=1.14.0; extra == "pandas" in /azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472/lib/python3.6/site-packages (from azureml-dataprep[pandas]->-r /azureml-environment-setup/condaenv.nmiy_ci_.requirements.txt (line 2)) (1.19.1)
# Collecting opencensus<1.0.0,>=0.7.13
#   Downloading opencensus-0.8.0-py2.py3-none-any.whl (128 kB)
# Collecting requests>=2.19.0
#   Downloading requests-2.26.0-py2.py3-none-any.whl (62 kB)
# Collecting psutil>=5.6.3
#   Downloading psutil-5.8.0-cp36-cp36m-manylinux2010_x86_64.whl (291 kB)
# Collecting contextlib2<22.0.0
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting jmespath<1.0.0
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied, skipping upgrade: pytz in /azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472/lib/python3.6/site-packages (from azureml-core~=1.35.0->azureml-defaults->-r /azureml-environment-setup/condaenv.nmiy_ci_.requirements.txt (line 1)) (2020.1)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Requirement already satisfied, skipping upgrade: python-dateutil<3.0.0,>=2.7.3 in /azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472/lib/python3.6/site-packages (from azureml-core~=1.35.0->azureml-defaults->-r /azureml-environment-setup/condaenv.nmiy_ci_.requirements.txt (line 1)) (2.8.1)
# Collecting ndg-httpsclient<=0.5.1
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting ruamel.yaml<=0.17.16,>=0.17.10
#   Downloading ruamel.yaml-0.17.16-py3-none-any.whl (109 kB)
# Collecting PyJWT<3.0.0
#   Downloading PyJWT-2.3.0-py3-none-any.whl (16 kB)
# Collecting pathspec<1.0.0
#   Downloading pathspec-0.9.0-py2.py3-none-any.whl (31 kB)
# Collecting adal<=1.2.7,>=1.2.0
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-13.0.0-py2.py3-none-any.whl (1.3 MB)
# Collecting urllib3<=1.26.6,>=1.23
#   Downloading urllib3-1.26.6-py2.py3-none-any.whl (138 kB)
# Collecting jsonpickle<3.0.0
#   Downloading jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<4.0.0
#   Downloading cryptography-3.4.8-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
# Collecting SecretStorage<4.0.0
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-8.2.0-py2.py3-none-any.whl (928 kB)
# Collecting msrestazure<=0.6.4,>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting docker<6.0.0
#   Downloading docker-5.0.3-py2.py3-none-any.whl (146 kB)
# Collecting azure-common<2.0.0,>=1.1.12
#   Downloading azure_common-1.1.27-py2.py3-none-any.whl (12 kB)
# Collecting azure-mgmt-keyvault<10.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-9.2.0-py2.py3-none-any.whl (412 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting pyopenssl<21.0.0
#   Downloading pyOpenSSL-20.0.1-py2.py3-none-any.whl (54 kB)
# Collecting msrest<1.0.0,>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Requirement already satisfied, skipping upgrade: setuptools>=3.0 in /azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472/lib/python3.6/site-packages (from gunicorn==20.1.0->azureml-defaults->-r /azureml-environment-setup/condaenv.nmiy_ci_.requirements.txt (line 1)) (50.3.0.post20201006)
# Collecting fusepy<4.0.0,>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.10-py2.py3-none-any.whl (55 kB)
# Collecting inference-schema==1.3.0
#   Downloading inference_schema-1.3.0-py3-none-any.whl (19 kB)
# Collecting msal<2.0.0,>=1.12.0
#   Downloading msal-1.16.0-py2.py3-none-any.whl (78 kB)
# Collecting azure-core<2.0.0,>=1.11.0
#   Downloading azure_core-1.19.1-py2.py3-none-any.whl (176 kB)
# Requirement already satisfied, skipping upgrade: six>=1.12.0 in /azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472/lib/python3.6/site-packages (from azure-identity==1.7.0->azureml-dataprep[pandas]->-r /azureml-environment-setup/condaenv.nmiy_ci_.requirements.txt (line 2)) (1.15.0)
# Collecting msal-extensions~=0.3.0
#   Downloading msal_extensions-0.3.0-py2.py3-none-any.whl (16 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.6.0-py2.py3-none-any.whl (19 kB)
# Collecting opencensus-context==0.1.2
#   Downloading opencensus_context-0.1.2-py2.py3-none-any.whl (4.4 kB)
# Collecting google-api-core<3.0.0,>=1.0.0; python_version >= "3.6"
#   Downloading google_api_core-2.2.2-py2.py3-none-any.whl (95 kB)
# Collecting idna<4,>=2.5; python_version >= "3"
#   Downloading idna-3.3-py3-none-any.whl (61 kB)
# Collecting charset-normalizer~=2.0.0; python_version >= "3"
#   Downloading charset_normalizer-2.0.7-py3-none-any.whl (38 kB)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472/lib/python3.6/site-packages (from requests>=2.19.0->opencensus-ext-azure==1.0.8->azureml-defaults->-r /azureml-environment-setup/condaenv.nmiy_ci_.requirements.txt (line 1)) (2020.6.20)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.10"
#   Downloading ruamel.yaml.clib-0.2.6-cp36-cp36m-manylinux1_x86_64.whl (552 kB)
# Collecting importlib-metadata; python_version < "3.8"
#   Downloading importlib_metadata-4.8.1-py3-none-any.whl (17 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.15.0-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (405 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.7.1-py3-none-any.whl (54 kB)
# Collecting azure-mgmt-core<2.0.0,>=1.2.0
#   Downloading azure_mgmt_core-1.3.0-py2.py3-none-any.whl (25 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.2.1-py2.py3-none-any.whl (52 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-3.0.2-py3-none-any.whl (133 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-2.0.1-py3-none-any.whl (18 kB)
# Collecting click>=5.1
#   Downloading click-8.0.3-py3-none-any.whl (97 kB)
# Collecting wrapt<=1.12.1,>=1.11.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Collecting portalocker~=1.0; platform_system != "Windows"
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Collecting contextvars; python_version >= "3.6" and python_version < "3.7"
#   Downloading contextvars-2.4.tar.gz (9.6 kB)
# Collecting googleapis-common-protos<2.0dev,>=1.52.0
#   Downloading googleapis_common_protos-1.53.0-py2.py3-none-any.whl (198 kB)
# Collecting google-auth<3.0dev,>=1.25.0
#   Downloading google_auth-2.3.3-py2.py3-none-any.whl (155 kB)
# Collecting protobuf>=3.12.0
#   Downloading protobuf-3.19.1-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# Collecting zipp>=0.5
#   Downloading zipp-3.6.0-py3-none-any.whl (5.3 kB)
# Collecting typing-extensions>=3.6.4; python_version < "3.8"
#   Downloading typing_extensions-3.10.0.2-py3-none-any.whl (26 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.0.1-cp36-cp36m-manylinux2010_x86_64.whl (30 kB)
# Collecting immutables>=0.9
#   Downloading immutables-0.16-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (103 kB)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.4-py3-none-any.whl (10 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting rsa<5,>=3.1.4; python_version >= "3.6"
#   Downloading rsa-4.7.2-py3-none-any.whl (34 kB)
# Building wheels for collected packages: json-logging-py, fusepy, wrapt, contextvars
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3924 sha256=779b81814b67ede291d3d50d98cc7a5ef92d5083bd96afab019688618c2749c1
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10504 sha256=5d869e2fdd0c38547cd3b6b1500c4e0cad0d028d46aa2c5308ccf23b9a238948
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for wrapt (setup.py): started
#   Building wheel for wrapt (setup.py): finished with status 'done'
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp36-cp36m-linux_x86_64.whl size=69876 sha256=716633c2f6d3201d1fe9e7ae95ebe5194b3be84e2c60d4f5d01d551f5770f4d7
#   Stored in directory: /root/.cache/pip/wheels/32/42/7f/23cae9ff6ef66798d00dc5d659088e57dbba01566f6c60db63
#   Building wheel for contextvars (setup.py): started
#   Building wheel for contextvars (setup.py): finished with status 'done'
#   Created wheel for contextvars: filename=contextvars-2.4-py3-none-any.whl size=7665 sha256=235a0ea385aeea5ddab379a107075eb71552869bde4b10ddb30d917c1a56b193
#   Stored in directory: /root/.cache/pip/wheels/41/11/53/911724983aa48deb94792432e14e518447212dd6c5477d49d3
# Successfully built json-logging-py fusepy wrapt contextvars
# Installing collected packages: typing-extensions, immutables, contextvars, opencensus-context, idna, charset-normalizer, urllib3, requests, protobuf, googleapis-common-protos, cachetools, pyasn1, pyasn1-modules, rsa, google-auth, google-api-core, opencensus, psutil, opencensus-ext-azure, werkzeug, contextlib2, backports.weakref, backports.tempfile, jmespath, pycparser, cffi, cryptography, PyJWT, adal, isodate, oauthlib, requests-oauthlib, msrest, msrestazure, azure-common, azure-mgmt-storage, pyopenssl, ndg-httpsclient, azure-mgmt-authorization, ruamel.yaml.clib, ruamel.yaml, pathspec, azure-mgmt-resource, zipp, importlib-metadata, jsonpickle, jeepney, SecretStorage, azure-core, azure-mgmt-core, azure-mgmt-containerregistry, websocket-client, docker, azure-mgmt-keyvault, azure-graphrbac, azureml-core, gunicorn, msal, portalocker, msal-extensions, azure-identity, distro, dotnetcore2, cloudpickle, azureml-dataprep-rslex, azureml-dataprep-native, pyarrow, azureml-dataprep, fusepy, azureml-dataset-runtime, configparser, MarkupSafe, Jinja2, itsdangerous, click, flask, applicationinsights, wrapt, inference-schema, azureml-inference-server-http, json-logging-py, azureml-defaults
# Successfully installed Jinja2-3.0.2 MarkupSafe-2.0.1 PyJWT-2.3.0 SecretStorage-3.3.1 adal-1.2.7 applicationinsights-0.11.10 azure-common-1.1.27 azure-core-1.19.1 azure-graphrbac-0.61.1 azure-identity-1.7.0 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-8.2.0 azure-mgmt-core-1.3.0 azure-mgmt-keyvault-9.2.0 azure-mgmt-resource-13.0.0 azure-mgmt-storage-11.2.0 azureml-core-1.35.0.post1 azureml-dataprep-2.24.0 azureml-dataprep-native-38.0.0 azureml-dataprep-rslex-2.0.0 azureml-dataset-runtime-1.35.0 azureml-defaults-1.35.0 azureml-inference-server-http-0.3.2 backports.tempfile-1.0 backports.weakref-1.0.post1 cachetools-4.2.4 cffi-1.15.0 charset-normalizer-2.0.7 click-8.0.3 cloudpickle-1.6.0 configparser-3.7.4 contextlib2-21.6.0 contextvars-2.4 cryptography-3.4.8 distro-1.6.0 docker-5.0.3 dotnetcore2-2.1.21 flask-1.0.3 fusepy-3.0.1 google-api-core-2.2.2 google-auth-2.3.3 googleapis-common-protos-1.53.0 gunicorn-20.1.0 idna-3.3 immutables-0.16 importlib-metadata-4.8.1 inference-schema-1.3.0 isodate-0.6.0 itsdangerous-2.0.1 jeepney-0.7.1 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-2.0.0 msal-1.16.0 msal-extensions-0.3.0 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.1.1 opencensus-0.8.0 opencensus-context-0.1.2 opencensus-ext-azure-1.0.8 pathspec-0.9.0 portalocker-1.7.1 protobuf-3.19.1 psutil-5.8.0 pyarrow-6.0.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 pycparser-2.20 pyopenssl-20.0.1 requests-2.26.0 requests-oauthlib-1.3.0 rsa-4.7.2 ruamel.yaml-0.17.16 ruamel.yaml.clib-0.2.6 typing-extensions-3.10.0.2 urllib3-1.26.6 websocket-client-1.2.1 werkzeug-1.0.1 wrapt-1.12.1 zipp-3.6.0
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container 5fdfdbf58f4f
#  ---> 8d289f3204d6
# Step 9/19 : ENV PATH /azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472/bin:$PATH
#  ---> Running in 03b400cd6902
# Removing intermediate container 03b400cd6902
#  ---> 53bb598594ed
# Step 10/19 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> 9ed0ceb04922
# Step 11/19 : RUN echo "Copying environment context"
#  ---> Running in 539bad583fda
# Copying environment context
# Removing intermediate container 539bad583fda
#  ---> 0c4a3083bca7
# Step 12/19 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> 550c1005368f
# Step 13/19 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472
#  ---> Running in 423648e54e86
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container 423648e54e86
#  ---> 98870e730474
# Step 14/19 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472
#  ---> Running in 4b0ec5f2b972
# Removing intermediate container 4b0ec5f2b972
#  ---> f3f997d98107
# Step 15/19 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472/lib:$LD_LIBRARY_PATH
#  ---> Running in 1457a740c388
# Removing intermediate container 1457a740c388
#  ---> 58efed219c0c
# Step 16/19 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> b7948c29a390
# Step 17/19 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in f1f1a680b803
# Removing intermediate container f1f1a680b803
#  ---> 300e23a118a8
# Step 18/19 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in cccd9d4bb490
# Removing intermediate container cccd9d4bb490
#  ---> 3c4d3d54b85f
# Step 19/19 : CMD ["bash"]
#  ---> Running in 2ad2b242a74a
# Removing intermediate container 2ad2b242a74a
#  ---> 05d739fa37bd
# Successfully built 05d739fa37bd
# Successfully tagged fd2bda387b2344cc8ecc8368b45be706.azurecr.io/azureml/azureml_74b5d7b1bfec63ece12721fc9d263e9a:latest
# Successfully tagged fd2bda387b2344cc8ecc8368b45be706.azurecr.io/azureml/azureml_74b5d7b1bfec63ece12721fc9d263e9a:1
# 2021/11/02 22:59:27 Successfully executed container: acb_step_0
# 2021/11/02 22:59:27 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/11/02 22:59:27 Pushing image: fd2bda387b2344cc8ecc8368b45be706.azurecr.io/azureml/azureml_74b5d7b1bfec63ece12721fc9d263e9a:1, attempt 1
# The push refers to repository [fd2bda387b2344cc8ecc8368b45be706.azurecr.io/azureml/azureml_74b5d7b1bfec63ece12721fc9d263e9a]
# f0b5713271c3: Preparing
# c333fe7e06da: Preparing
# 9bb3586edcf3: Preparing
# 93f05d400853: Preparing
# 3dc3d221ab23: Preparing
# d44c36b7e622: Preparing
# 4132bac263e0: Preparing
# 90c5419666c3: Preparing
# b5a6b6246bca: Preparing
# 74fb2b1f9cd0: Preparing
# a538760f4a1a: Preparing
# a5fe9a2519ae: Preparing
# ed55807831e0: Preparing
# 8629fec416c4: Preparing
# 58225d650dbb: Preparing
# 1073c0ca7301: Preparing
# be8950179889: Preparing
# 6babb56be259: Preparing
# d44c36b7e622: Waiting
# 4132bac263e0: Waiting
# 90c5419666c3: Waiting
# b5a6b6246bca: Waiting
# a5fe9a2519ae: Waiting
# ed55807831e0: Waiting
# 74fb2b1f9cd0: Waiting
# a538760f4a1a: Waiting
# 8629fec416c4: Waiting
# 58225d650dbb: Waiting
# 1073c0ca7301: Waiting
# be8950179889: Waiting
# 6babb56be259: Waiting
# 93f05d400853: Pushed
# 9bb3586edcf3: Pushed
# f0b5713271c3: Pushed
# c333fe7e06da: Pushed
# 4132bac263e0: Pushed
# d44c36b7e622: Pushed
# 90c5419666c3: Pushed
# b5a6b6246bca: Pushed
# 74fb2b1f9cd0: Pushed
# a538760f4a1a: Pushed
# a5fe9a2519ae: Pushed
# ed55807831e0: Pushed
# 58225d650dbb: Pushed
# 1073c0ca7301: Pushed
# 6babb56be259: Pushed
# 8629fec416c4: Pushed
#
# be8950179889: Pushed
# 3dc3d221ab23: Pushed
# 1: digest: sha256:e2701717fa037fa4e4b0e1fc80dd0b4f36532d4afba51d0443c8b098bb501158 size: 4099
# 2021/11/02 23:01:21 Successfully pushed image: fd2bda387b2344cc8ecc8368b45be706.azurecr.io/azureml/azureml_74b5d7b1bfec63ece12721fc9d263e9a:1
# 2021/11/02 23:01:21 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/11/02 23:01:21 Pushing image: fd2bda387b2344cc8ecc8368b45be706.azurecr.io/azureml/azureml_74b5d7b1bfec63ece12721fc9d263e9a:latest, attempt 1
# The push refers to repository [fd2bda387b2344cc8ecc8368b45be706.azurecr.io/azureml/azureml_74b5d7b1bfec63ece12721fc9d263e9a]
# f0b5713271c3: Preparing
# c333fe7e06da: Preparing
# 9bb3586edcf3: Preparing
# 93f05d400853: Preparing
# 3dc3d221ab23: Preparing
# d44c36b7e622: Preparing
# 4132bac263e0: Preparing
# 90c5419666c3: Preparing
# b5a6b6246bca: Preparing
# 74fb2b1f9cd0: Preparing
# a538760f4a1a: Preparing
# a5fe9a2519ae: Preparing
# ed55807831e0: Preparing
# 8629fec416c4: Preparing
# 58225d650dbb: Preparing
# 1073c0ca7301: Preparing
# be8950179889: Preparing
# 6babb56be259: Preparing
# 74fb2b1f9cd0: Waiting
# a538760f4a1a: Waiting
# a5fe9a2519ae: Waiting
# ed55807831e0: Waiting
# 8629fec416c4: Waiting
# 58225d650dbb: Waiting
# 1073c0ca7301: Waiting
# be8950179889: Waiting
# 6babb56be259: Waiting
# d44c36b7e622: Waiting
# 4132bac263e0: Waiting
# 90c5419666c3: Waiting
# b5a6b6246bca: Waiting
# f0b5713271c3: Layer already exists
# c333fe7e06da: Layer already exists
# 9bb3586edcf3: Layer already exists
# 3dc3d221ab23: Layer already exists
# 93f05d400853: Layer already exists
# d44c36b7e622: Layer already exists
# b5a6b6246bca: Layer already exists
# 74fb2b1f9cd0: Layer already exists
# 4132bac263e0: Layer already exists
# a538760f4a1a: Layer already exists
# a5fe9a2519ae: Layer already exists
# ed55807831e0: Layer already exists
# 58225d650dbb: Layer already exists
# 8629fec416c4: Layer already exists
# 1073c0ca7301: Layer already exists
# be8950179889: Layer already exists
# 6babb56be259: Layer already exists
# 90c5419666c3: Layer already exists
# latest: digest: sha256:e2701717fa037fa4e4b0e1fc80dd0b4f36532d4afba51d0443c8b098bb501158 size: 4099
# 2021/11/02 23:01:23 Successfully pushed image: fd2bda387b2344cc8ecc8368b45be706.azurecr.io/azureml/azureml_74b5d7b1bfec63ece12721fc9d263e9a:latest
# 2021/11/02 23:01:23 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 286.029828)
# 2021/11/02 23:01:23 Populating digests for step ID: acb_step_0...
# 2021/11/02 23:01:25 Successfully populated digests for step ID: acb_step_0
# 2021/11/02 23:01:25 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 113.892635)
# 2021/11/02 23:01:25 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 2.228360)
# 2021/11/02 23:01:25 The following dependencies were found:
# 2021/11/02 23:01:25
# - image:
#     registry: fd2bda387b2344cc8ecc8368b45be706.azurecr.io
#     repository: azureml/azureml_74b5d7b1bfec63ece12721fc9d263e9a
#     tag: latest
#     digest: sha256:e2701717fa037fa4e4b0e1fc80dd0b4f36532d4afba51d0443c8b098bb501158
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-ubuntu18.04
#     tag: 20210922.v1
#     digest: sha256:bfed4edd2085c7fa221827c7ea4d1dc8c48fd52d64b9411260bf94f7f6fae31a
#   git: {}
# - image:
#     registry: fd2bda387b2344cc8ecc8368b45be706.azurecr.io
#     repository: azureml/azureml_74b5d7b1bfec63ece12721fc9d263e9a
#     tag: "1"
#     digest: sha256:e2701717fa037fa4e4b0e1fc80dd0b4f36532d4afba51d0443c8b098bb501158
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-ubuntu18.04
#     tag: 20210922.v1
#     digest: sha256:bfed4edd2085c7fa221827c7ea4d1dc8c48fd52d64b9411260bf94f7f6fae31a
#   git: {}
#
#
# Run ID: ca1 was successful after 6m47s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_170b7270fe646618004ade86ec454d07d5f6a16ba19c49481980dff59b29f585_d.txt
# ========================================================================================================================
# 2021-11-02T23:09:25Z Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/mlop_14/azureml/afbedb46-4924-4cbe-abec-b867b68805e4/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/mlop_14/azureml/afbedb46-4924-4cbe-abec-b867b68805e4/caches/workspaceblobstore --file-cache-timeout-in-seconds=1000000 --cache-size-mb=24781 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/mlop_14/azureml/afbedb46-4924-4cbe-abec-b867b68805e4/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# 2021-11-02T23:09:25Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/mlop_14/azureml/afbedb46-4924-4cbe-abec-b867b68805e4/mounts/workspaceblobstore
# 2021-11-02T23:09:28Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-11-02T23:09:28Z Starting output-watcher...
# 2021-11-02T23:09:28Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-11-02T23:09:29Z Executing 'Copy ACR Details file' on 10.0.0.5
# 2021-11-02T23:09:29Z Copy ACR Details file succeeded on 10.0.0.5. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_74b5d7b1bfec63ece12721fc9d263e9a
# e4ca327ec0e7: Pulling fs layer
# f0fb8b64b41b: Pulling fs layer
# e43ee38068bf: Pulling fs layer
# 409df78264bc: Pulling fs layer
# a2eb44ae9dc0: Pulling fs layer
# b8ff7afa1c52: Pulling fs layer
# d92dd21f7e9a: Pulling fs layer
# 965946e36f3d: Pulling fs layer
# 9d3ce4a2dac8: Pulling fs layer
# de7a5b32ff49: Pulling fs layer
# 6321574af113: Pulling fs layer
# 20eef5bc6943: Pulling fs layer
# 5ece429a323e: Pulling fs layer
# 5ba7c195d87d: Pulling fs layer
# 7d458472bf46: Pulling fs layer
# 8080f47ab03d: Pulling fs layer
# 2fc212002413: Pulling fs layer
# 73221fa75935: Pulling fs layer
# 409df78264bc: Waiting
# a2eb44ae9dc0: Waiting
# b8ff7afa1c52: Waiting
# d92dd21f7e9a: Waiting
# 965946e36f3d: Waiting
# 9d3ce4a2dac8: Waiting
# de7a5b32ff49: Waiting
# 6321574af113: Waiting
# 20eef5bc6943: Waiting
# 5ece429a323e: Waiting
# 5ba7c195d87d: Waiting
# 7d458472bf46: Waiting
# 8080f47ab03d: Waiting
# 2fc212002413: Waiting
# 73221fa75935: Waiting
# e4ca327ec0e7: Verifying Checksum
# e4ca327ec0e7: Download complete
# e43ee38068bf: Verifying Checksum
# e43ee38068bf: Download complete
# 409df78264bc: Verifying Checksum
# 409df78264bc: Download complete
# f0fb8b64b41b: Verifying Checksum
# f0fb8b64b41b: Download complete
# b8ff7afa1c52: Verifying Checksum
# b8ff7afa1c52: Download complete
# a2eb44ae9dc0: Verifying Checksum
# a2eb44ae9dc0: Download complete
# d92dd21f7e9a: Verifying Checksum
# d92dd21f7e9a: Download complete
# 965946e36f3d: Verifying Checksum
# 965946e36f3d: Download complete
# 9d3ce4a2dac8: Verifying Checksum
# 9d3ce4a2dac8: Download complete
# de7a5b32ff49: Verifying Checksum
# de7a5b32ff49: Download complete
# 20eef5bc6943: Verifying Checksum
# 20eef5bc6943: Download complete
# 5ece429a323e: Verifying Checksum
# 5ece429a323e: Download complete
# e4ca327ec0e7: Pull complete
# 7d458472bf46: Verifying Checksum
# 7d458472bf46: Download complete
# 6321574af113: Verifying Checksum
# 6321574af113: Download complete
# 8080f47ab03d: Verifying Checksum
# 8080f47ab03d: Download complete
# 73221fa75935: Verifying Checksum
# 73221fa75935: Download complete
# 2fc212002413: Verifying Checksum
# 2fc212002413: Download complete
# 5ba7c195d87d: Verifying Checksum
# 5ba7c195d87d: Download complete
# f0fb8b64b41b: Pull complete
# e43ee38068bf: Pull complete
# 409df78264bc: Pull complete
# a2eb44ae9dc0: Pull complete
# b8ff7afa1c52: Pull complete
# d92dd21f7e9a: Pull complete
# 965946e36f3d: Pull complete
# 9d3ce4a2dac8: Pull complete
# de7a5b32ff49: Pull complete
# 6321574af113: Pull complete
# 20eef5bc6943: Pull complete
# 5ece429a323e: Pull complete
#
# Streaming azureml-logs/65_job_prep-tvmps_170b7270fe646618004ade86ec454d07d5f6a16ba19c49481980dff59b29f585_d.txt
# ===============================================================================================================
# [2021-11-02T23:10:28.792622] Entering job preparation.
# [2021-11-02T23:10:30.733383] Starting job preparation.
# [2021-11-02T23:10:30.733424] Extracting the control code.
# [2021-11-02T23:10:30.733793] Starting extract_project.
# [2021-11-02T23:10:30.733840] Starting to extract zip file.
# [2021-11-02T23:10:30.760017] Finished extracting zip file.
# [2021-11-02T23:10:30.763908] Using urllib.request Python 3.0 or later
# [2021-11-02T23:10:30.763960] Start fetching snapshots.
# [2021-11-02T23:10:30.764002] Start fetching snapshot.
# [2021-11-02T23:10:30.764021] Retrieving project from snapshot: 2e465b90-60b1-4702-a4a3-52f3e07c8935
# Starting the daemon thread to refresh tokens in background for process with pid = 43
# [2021-11-02T23:10:31.282472] Finished fetching snapshot.
# [2021-11-02T23:10:31.282511] Finished fetching snapshots.
# [2021-11-02T23:10:31.282536] Finished extract_project.
# [2021-11-02T23:10:31.282692] Finished fetching and extracting the control code.
# [2021-11-02T23:10:31.287030] downloadDataStore - Download from datastores if requested.
# [2021-11-02T23:10:31.288769] Start run_history_prep.
# [2021-11-02T23:10:31.295211] Entering context manager injector.
# Acquired lockfile /tmp/afbedb46-4924-4cbe-abec-b867b68805e4-datastore.lock to downloading input data references
# [2021-11-02T23:10:31.825865] downloadDataStore completed
# [2021-11-02T23:10:31.829399] Job preparation is complete.
#
# Streaming azureml-logs/75_job_post-tvmps_170b7270fe646618004ade86ec454d07d5f6a16ba19c49481980dff59b29f585_d.txt
# ===============================================================================================================
# [2021-11-02T23:10:50.933948] Entering job release
# [2021-11-02T23:10:51.922916] Starting job release
# [2021-11-02T23:10:51.923668] Logging experiment finalizing status in history service.
# [2021-11-02T23:10:51.924030] job release stage : upload_datastore starting...
# Starting the daemon thread to refresh tokens in background for process with pid = 315
# ...
# >>>   2021/11/02 23:13:21 Check if container cf5d83a2-f8a8-4b1b-a2f3-d2dca717b7ca already exist exited with 0,
# >>>
# >>>   2021/11/02 23:13:21 Check if container cf5d83a2-f8a8-4b1b-a2f3-d2dca717b7ca already exist exited with 0,
# >>>
# >>>   2021/11/02 23:13:21 Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# >>>   2021/11/02 23:13:21 Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# >>>   2021/11/02 23:13:21 containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-b52fb290dab35c0668e3bd7abf2e15e5-22fd69a71be7b65a-01 -sshRequired=false]
# >>>   2021/11/02 23:13:21 containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-b52fb290dab35c0668e3bd7abf2e15e5-22fd69a71be7b65a-01 -sshRequired=false]
# >>>   2021/11/02 23:13:22 Container ssh is not required for job type.
# >>>   2021/11/02 23:13:22 Starting docker container succeeded.
# >>>   2021/11/02 23:13:22 Starting docker container succeeded.
# >>>   2021/11/02 23:13:22 Disk space after starting docker container: 23317MB
# >>>   2021/11/02 23:13:22 SidecarEnabled:: isDetonationChamber: false, useDockerContainer: true
# >>>   2021/11/02 23:13:22 SidecarEnabled:: AmlDatasetContextManagerConfig exists: false
# >>>   2021/11/02 23:13:22 SidecarEnabled:: sidecar not enabled
# >>>   2021/11/02 23:13:22 Begin execution of runSpecialJobTask
# >>>   2021/11/02 23:13:22 Creating directory at $AZUREML_LOGDIRECTORY_PATH
# >>>   2021/11/02 23:13:22 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mlop_14/azureml/cf5d83a2-f8a8-4b1b-a2f3-d2dca717b7ca/wd/azureml/cf5d83a2-f8a8-4b1b-a2f3-d2dca717b7ca/azureml-logs
# >>>   2021/11/02 23:13:22 runSpecialJobTask: os.GetEnv constants.StdouterrDir: /mnt/batch/tasks/shared/LS_root/jobs/mlop_14/azureml/cf5d83a2-f8a8-4b1b-a2f3-d2dca717b7ca/wd/azureml/cf5d83a2-f8a8-4b1b-a2f3-d2dca717b7ca/azureml_compute_logs
# >>>   2021/11/02 23:13:22 runSpecialJobTask: Raw cmd for preparation is passed is: /azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472/bin/python /mnt/batch/tasks/shared/LS_root/jobs/mlop_14/azureml/cf5d83a2-f8a8-4b1b-a2f3-d2dca717b7ca/mounts/workspaceblobstore/azureml/cf5d83a2-f8a8-4b1b-a2f3-d2dca717b7ca-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"2e465b90-60b1-4702-a4a3-52f3e07c8935","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/11/02 23:13:22 runSpecialJobTask: stdout path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/mlop_14/azureml/cf5d83a2-f8a8-4b1b-a2f3-d2dca717b7ca/wd/azureml/cf5d83a2-f8a8-4b1b-a2f3-d2dca717b7ca/azureml_compute_logs/65_job_prep-tvmps_170b7270fe646618004ade86ec454d07d5f6a16ba19c49481980dff59b29f585_d.txt
# >>>   2021/11/02 23:13:22 runSpecialJobTask: stderr path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/mlop_14/azureml/cf5d83a2-f8a8-4b1b-a2f3-d2dca717b7ca/wd/azureml/cf5d83a2-f8a8-4b1b-a2f3-d2dca717b7ca/azureml_compute_logs/65_job_prep-tvmps_170b7270fe646618004ade86ec454d07d5f6a16ba19c49481980dff59b29f585_d.txt
# >>>   2021/11/02 23:13:22 native cmd: export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/3e308302-e9b1-4e72-9c55-3e80663613d2/job-1/cf5d83a2-f8a8-4b1b-a_c06ce7d6-981a-4824-a8e5-682ec2e78e29/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/mlop_14/azureml/cf5d83a2-f8a8-4b1b-a2f3-d2dca717b7ca/wd/azureml/cf5d83a2-f8a8-4b1b-a2f3-d2dca717b7ca;/azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472/bin/python /mnt/batch/tasks/shared/LS_root/jobs/mlop_14/azureml/cf5d83a2-f8a8-4b1b-a2f3-d2dca717b7ca/mounts/workspaceblobstore/azureml/cf5d83a2-f8a8-4b1b-a2f3-d2dca717b7ca-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"2e465b90-60b1-4702-a4a3-52f3e07c8935","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/11/02 23:13:22 runSpecialJobTask: commons.GetOsPlatform(): ubuntu
# >>>   2021/11/02 23:13:22 runSpecialJobTask: Running cmd: /usr/bin/docker exec -e AZUREML_SDK_TRACEPARENT=00-b52fb290dab35c0668e3bd7abf2e15e5-2fd09d26995abfa2-01 -t cf5d83a2-f8a8-4b1b-a2f3-d2dca717b7ca bash -c if [ -f ~/.bashrc ]; then PS1_back=$PS1; PS1='$'; . ~/.bashrc; PS1=$PS1_back; fi;PATH=$PATH:$AZ_BATCH_NODE_STARTUP_DIR/wd/;export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/3e308302-e9b1-4e72-9c55-3e80663613d2/job-1/cf5d83a2-f8a8-4b1b-a_c06ce7d6-981a-4824-a8e5-682ec2e78e29/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/mlop_14/azureml/cf5d83a2-f8a8-4b1b-a2f3-d2dca717b7ca/wd/azureml/cf5d83a2-f8a8-4b1b-a2f3-d2dca717b7ca;/azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472/bin/python /mnt/batch/tasks/shared/LS_root/jobs/mlop_14/azureml/cf5d83a2-f8a8-4b1b-a2f3-d2dca717b7ca/mounts/workspaceblobstore/azureml/cf5d83a2-f8a8-4b1b-a2f3-d2dca717b7ca-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"2e465b90-60b1-4702-a4a3-52f3e07c8935","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/11/02 23:13:24 Attempt 1 of http call to https://eastus.api.azureml.ms/history/v1.0/private/subscriptions/6d705e60-c254-4179-9abe-b484e8ac71ef/resourceGroups/MLOP/providers/Microsoft.MachineLearningServices/workspaces/MLOP_14/runs/cf5d83a2-f8a8-4b1b-a2f3-d2dca717b7ca/spans
# >>>   2021/11/02 23:13:26 containerName:cf5d83a2-f8a8-4b1b-a2f3-d2dca717b7ca
# >>>   2021/11/02 23:13:26 sidecar containerName:cf5d83a2-f8a8-4b1b-a2f3-d2dca717b7ca
# >>>   2021/11/02 23:13:26 Docker Version that this nodes use are: 19.03.14+azure
# >>>
# >>>   2021/11/02 23:13:26 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/11/02 23:13:26 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/11/02 23:13:26 sidecar dockerLauncher:docker
# >>>   2021/11/02 23:13:26 sidecarContainerId:2b56c36e5ec80add153e1389febef16bd0e4107a619ea589fe4e8185d5ddfb0f
# >>>   2021/11/02 23:13:26 Docker Version that this nodes use are: 19.03.14+azure
# >>>
# >>>   2021/11/02 23:13:26 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/11/02 23:13:26 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/11/02 23:13:26 Docker logs for cf5d83a2-f8a8-4b1b-a2f3-d2dca717b7ca
# >>>
# >>>   2021/11/02 23:13:26 runSpecialJobTask: job preparation exited with code 0 and err <nil>
# >>>
# >>>   2021/11/02 23:13:26 runSpecialJobTask: preparation: [2021-11-02T23:13:23.179764] Entering job preparation.
# >>>   2021/11/02 23:13:26 runSpecialJobTask: preparation: [2021-11-02T23:13:24.853061] Starting job preparation.
# >>>   2021/11/02 23:13:26 runSpecialJobTask: preparation: [2021-11-02T23:13:24.853103] Extracting the control code.
# >>>   2021/11/02 23:13:26 runSpecialJobTask: preparation: [2021-11-02T23:13:24.853467] Starting extract_project.
# >>>   2021/11/02 23:13:26 runSpecialJobTask: preparation: [2021-11-02T23:13:24.853517] Starting to extract zip file.
# >>>   2021/11/02 23:13:26 runSpecialJobTask: preparation: [2021-11-02T23:13:24.877703] Finished extracting zip file.
# >>>   2021/11/02 23:13:26 runSpecialJobTask: preparation: [2021-11-02T23:13:24.881453] Using urllib.request Python 3.0 or later
# >>>   2021/11/02 23:13:26 runSpecialJobTask: preparation: [2021-11-02T23:13:24.881501] Start fetching snapshots.
# >>>   2021/11/02 23:13:26 runSpecialJobTask: preparation: [2021-11-02T23:13:24.881533] Start fetching snapshot.
# >>>   2021/11/02 23:13:26 runSpecialJobTask: preparation: [2021-11-02T23:13:24.881552] Retrieving project from snapshot: 2e465b90-60b1-4702-a4a3-52f3e07c8935
# >>>   2021/11/02 23:13:26 runSpecialJobTask: preparation: Starting the daemon thread to refresh tokens in background for process with pid = 44
# >>>   2021/11/02 23:13:26 runSpecialJobTask: preparation: [2021-11-02T23:13:25.690474] Finished fetching snapshot.
# >>>   2021/11/02 23:13:26 runSpecialJobTask: preparation: [2021-11-02T23:13:25.690515] Finished fetching snapshots.
# >>>   2021/11/02 23:13:26 runSpecialJobTask: preparation: [2021-11-02T23:13:25.690522] Finished extract_project.
# >>>   2021/11/02 23:13:26 runSpecialJobTask: preparation: [2021-11-02T23:13:25.690624] Finished fetching and extracting the control code.
# >>>   2021/11/02 23:13:26 runSpecialJobTask: preparation: [2021-11-02T23:13:25.694718] downloadDataStore - Download from datastores if requested.
# >>>   2021/11/02 23:13:26 runSpecialJobTask: preparation: [2021-11-02T23:13:25.696121] Start run_history_prep.
# >>>   2021/11/02 23:13:26 runSpecialJobTask: preparation: [2021-11-02T23:13:25.709921] Entering context manager injector.
# >>>   2021/11/02 23:13:26 runSpecialJobTask: preparation: Acquired lockfile /tmp/cf5d83a2-f8a8-4b1b-a2f3-d2dca717b7ca-datastore.lock to downloading input data references
# >>>   2021/11/02 23:13:26 runSpecialJobTask: preparation: [2021-11-02T23:13:26.225173] downloadDataStore completed
# >>>   2021/11/02 23:13:26 runSpecialJobTask: preparation: [2021-11-02T23:13:26.228624] Job preparation is complete.
# >>>   2021/11/02 23:13:26 DockerSideCarContainerLogs:
# >>>
# >>>   2021/11/02 23:13:26 DockerSideCarContainerLogs End
# >>>   2021/11/02 23:13:26 Execution of runSpecialJobTask completed
# >>>   2021/11/02 23:13:26 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# >>>   Stopped: false
# >>>   OriginalData: 3
# >>>   FilteredData: 0.
# >>>   2021/11/02 23:13:26 Process Exiting with Code:  0
# >>>   2021/11/02 23:13:27 All App Insights Logs was sent successfully or the close timeout of 10 was reached
# >>>
# 2021-11-02T23:13:27Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-11-02T23:13:27Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-11-02T23:13:27Z 127.0.0.1 slots=2 max-slots=2
# 2021-11-02T23:13:27Z launching Custom job
#
# Streaming azureml-logs/75_job_post-tvmps_170b7270fe646618004ade86ec454d07d5f6a16ba19c49481980dff59b29f585_d.txt
# ===============================================================================================================
# [2021-11-02T23:13:39.399943] Entering job release
# [2021-11-02T23:13:40.390308] Starting job release
# [2021-11-02T23:13:40.391116] Logging experiment finalizing status in history service.
# [2021-11-02T23:13:40.391364] job release stage : upload_datastore starting...
# [2021-11-02T23:13:40.391759] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-11-02T23:13:40.391800] job release stage : execute_job_release starting...
# Starting the daemon thread to refresh tokens in background for process with pid = 161
# [2021-11-02T23:13:40.392981] job release stage : copy_batchai_cached_logs starting...
# [2021-11-02T23:13:40.393228] job release stage : copy_batchai_cached_logs completed...
# [2021-11-02T23:13:40.401925] Entering context manager injector.
# [2021-11-02T23:13:40.428322] job release stage : upload_datastore completed...
# [2021-11-02T23:13:40.490251] job release stage : send_run_telemetry starting...
# [2021-11-02T23:13:40.530056] get vm size and vm region successfully.
# [2021-11-02T23:13:40.549467] get compute meta data successfully.
# [2021-11-02T23:13:40.661146] job release stage : execute_job_release completed...
# [2021-11-02T23:13:40.852091] post artifact meta request successfully.
# [2021-11-02T23:13:40.886379] upload compute record artifact successfully.
# [2021-11-02T23:13:40.886446] job release stage : send_run_telemetry completed...
# [2021-11-02T23:13:40.886723] Job release is complete
#
# StepRun(Train and Register Model) Execution Summary
# ====================================================
# StepRun( Train and Register Model ) Status: Failed
#
# Warnings:
# {
#   "error": {
#     "code": "UserError",
#     "severity": null,
#     "message": "AzureMLCompute job failed.\nJobFailed: Submitted script failed with a non-zero exit code; see the driver log file for details.\n\tReason: Job failed with non-zero exit Code",
#     "messageFormat": "{Message}",
#     "messageParameters": {
#       "Message": "AzureMLCompute job failed.\nJobFailed: Submitted script failed with a non-zero exit code; see the driver log file for details.\n\tReason: Job failed with non-zero exit Code"
#     },
#     "referenceCode": null,
#     "detailsUri": null,
#     "target": null,
#     "details": [],
#     "innerError": {
#       "code": "UserTrainingScriptFailed",
#       "innerError": null
#     },
#     "debugInfo": null,
#     "additionalInfo": null
#   },
#   "correlation": {
#     "operation": "24affdc9b00ae24aad14ee54cfddc199",
#     "request": "8e02eac871150ef6"
#   },
#   "environment": "eastus",
#   "location": "eastus",
#   "time": "2021-11-02T23:13:51.7913109+00:00",
#   "componentName": "globaljobdispatcher"
# }
# ---------------------------------------------------------------------------
# ActivityFailedException                   Traceback (most recent call last)
# <ipython-input-15-eedec3492e19> in <module>
#      13 print("Pipeline submitted for execution.")
#      14 RunDetails(pipeline_run).show()
# ---> 15 pipeline_run.wait_for_completion(show_output=True)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/azureml/pipeline/core/run.py in wait_for_completion(self, show_output, timeout_seconds, raise_on_error)
#     293                             print('\n')
#     294                             try:
# --> 295                                 step_run.wait_for_completion(timeout_seconds=timeout_seconds - time_elapsed,
#     296                                                              raise_on_error=raise_on_error)
#     297                             except TypeError as e:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/azureml/pipeline/core/run.py in wait_for_completion(self, show_output, timeout_seconds, raise_on_error)
#     735         if show_output:
#     736             try:
# --> 737                 return self._stream_run_output(timeout_seconds=timeout_seconds,
#     738                                                raise_on_error=raise_on_error)
#     739             except KeyboardInterrupt:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/azureml/pipeline/core/run.py in _stream_run_output(self, timeout_seconds, raise_on_error)
#     828             print(json.dumps(error, indent=4))
#     829         if error and raise_on_error:
# --> 830             raise ActivityFailedException(error_details=json.dumps(error, indent=4))
#     831
#     832         print(final_details)
#
# ActivityFailedException: ActivityFailedException:
# 	Message: Activity Failed:
# {
#     "error": {
#         "code": "UserError",
#         "message": "User program failed with IndexError: index 1 is out of bounds for axis 1 with size 1",
#         "messageParameters": {},
#         "detailsUri": "https://aka.ms/azureml-run-troubleshooting",
#         "details": []
#     },
#     "time": "0001-01-01T00:00:00.000Z"
# }
# 	InnerException None
# 	ErrorResponse
# {
#     "error": {
#         "message": "Activity Failed:\n{\n    \"error\": {\n        \"code\": \"UserError\",\n        \"message\": \"User program failed with IndexError: index 1 is out of bounds for axis 1 with size 1\",\n        \"messageParameters\": {},\n        \"detailsUri\": \"https://aka.ms/azureml-run-troubleshooting\",\n        \"details\": []\n    },\n    \"time\": \"0001-01-01T00:00:00.000Z\"\n}"
#     }
# }
