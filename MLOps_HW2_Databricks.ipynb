# %%
import pandas as pd
import numpy as np
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Read from Spark

df1 = spark.read.format("csv").load("dbfs:/FileStore/shared_uploads/mucongl@uchicago.edu/df_og.csv", header = "True")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df1)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# Read from Pandas 
# NOT WORKING

import pandas as pd

df2 = pd.read_csv("/dbfs/FileStore/shared_uploads/mucongl@uchicago.edu/df_og.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">FileNotFoundError</span>                         Traceback (most recent call last)
# ...

# %%
# Try following the "Quickstart Notebook" and first saving it in a "delta" location

df1.write.format("delta").mode("overwrite").save("/delta/hw2_df1")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AnalysisException</span>                         Traceback (most recent call last)
# ...

# %%
# But it's still not working 
df2 = pd.read_csv("/delta/hw2_df1/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">FileNotFoundError</span>                         Traceback (most recent call last)
# ...

# %%
# Turn the PySpark Dataframe into a Pandas Dataframe

df = df1.toPandas()
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>Attrition</th>
#       <th>BusinessTravel</th>
#       <th>DailyRate</th>
#       <th>Department</th>
#       <th>DistanceFromHome</th>
#       <th>Education</th>
#       <th>EducationField</th>
#       <th>EmployeeCount</th>
#       <th>EmployeeNumber</th>
#       <th>EnvironmentSatisfaction</th>
#       <th>HourlyRate</th>
#       <th>JobInvolvement</th>
#       <th>JobLevel</th>
#       <th>JobRole</th>
#       <th>JobSatisfaction</th>
#       <th>MonthlyIncome</th>
#       <th>NumCompaniesWorked</th>
#       <th>PercentSalaryHike</th>
#       <th>StandardHours</th>
# ...

# %%
# install MLFLOW

pip install mlflow
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Python interpreter will be restarted.
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status &#39;done&#39;
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status &#39;done&#39;
# ...
#   Created wheel for alembic: filename=alembic-1.4.1-py2.py3-none-any.whl size=158155 sha256=08e336f7bce65ad670f31db788dd27d6962cf31febd534e6360846e1858b62f6
#   Stored in directory: /root/.cache/pip/wheels/be/5d/0a/9e13f53f4f5dfb67cd8d245bb7cdffe12f135846f491a283e3
# ...

# %%
# Import ML flow to run and log the model ()

import mlflow
import mlflow.sklearn
import pandas as pd
import matplotlib.pyplot as plt
 
from numpy import savetxt
 
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_diabetes
 
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# All columns became categorical! Can't just "get_dummies"
df.info()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &#39;pandas.core.frame.DataFrame&#39;&gt;
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1470 non-null   object
#  1   Attrition                1470 non-null   object
#  2   BusinessTravel           1470 non-null   object
#  3   DailyRate                1470 non-null   object
#  4   Department               1470 non-null   object
#  5   DistanceFromHome         1470 non-null   object
#  6   Education                1470 non-null   object
# ...

# %%
# Categorical: 'Attrition', 'BusinessTravel', 'Department', 'EducationField', 'JobRole'

df_dum = pd.get_dummies(df[['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'JobRole']])
df_dum.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Attrition_No</th>
#       <th>Attrition_Yes</th>
#       <th>BusinessTravel_Non-Travel</th>
#       <th>BusinessTravel_Travel_Frequently</th>
#       <th>BusinessTravel_Travel_Rarely</th>
#       <th>Department_Human Resources</th>
#       <th>Department_Research &amp; Development</th>
#       <th>Department_Sales</th>
#       <th>EducationField_Human Resources</th>
#       <th>EducationField_Life Sciences</th>
#       <th>EducationField_Marketing</th>
#       <th>EducationField_Medical</th>
#       <th>EducationField_Other</th>
#       <th>EducationField_Technical Degree</th>
# ...

# %%
# Categorical columns are gone
df.info()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &#39;pandas.core.frame.DataFrame&#39;&gt;
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1470 non-null   object
#  1   DailyRate                1470 non-null   object
#  2   DistanceFromHome         1470 non-null   object
#  3   Education                1470 non-null   object
#  4   EmployeeCount            1470 non-null   object
#  5   EmployeeNumber           1470 non-null   object
#  6   EnvironmentSatisfaction  1470 non-null   object
# ...

# %%
df_final = pd.concat([df,df_dum], axis = 1)
df_final.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>DailyRate</th>
#       <th>DistanceFromHome</th>
#       <th>Education</th>
#       <th>EmployeeCount</th>
#       <th>EmployeeNumber</th>
#       <th>EnvironmentSatisfaction</th>
#       <th>HourlyRate</th>
#       <th>JobInvolvement</th>
#       <th>JobLevel</th>
#       <th>JobSatisfaction</th>
#       <th>MonthlyIncome</th>
#       <th>NumCompaniesWorked</th>
#       <th>PercentSalaryHike</th>
#       <th>StandardHours</th>
#       <th>StockOptionLevel</th>
#       <th>TotalWorkingYears</th>
#       <th>TrainingTimesLastYear</th>
#       <th>WorkLifeBalance</th>
# ...

# %%
df_final.info()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &#39;pandas.core.frame.DataFrame&#39;&gt;
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 45 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                1470 non-null   object
#  1   DailyRate                          1470 non-null   object
#  2   DistanceFromHome                   1470 non-null   object
#  3   Education                          1470 non-null   object
#  4   EmployeeCount                      1470 non-null   object
# ...

# %%
df_final2 = df_final.astype(int)
df_final2
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>DailyRate</th>
#       <th>DistanceFromHome</th>
#       <th>Education</th>
#       <th>EmployeeCount</th>
#       <th>EmployeeNumber</th>
#       <th>EnvironmentSatisfaction</th>
#       <th>HourlyRate</th>
#       <th>JobInvolvement</th>
#       <th>JobLevel</th>
#       <th>JobSatisfaction</th>
#       <th>MonthlyIncome</th>
#       <th>NumCompaniesWorked</th>
#       <th>PercentSalaryHike</th>
#       <th>StandardHours</th>
#       <th>StockOptionLevel</th>
#       <th>TotalWorkingYears</th>
#       <th>TrainingTimesLastYear</th>
#       <th>WorkLifeBalance</th>
# ...

# %%
df_final2.info()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &#39;pandas.core.frame.DataFrame&#39;&gt;
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 45 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                1470 non-null   int64
#  1   DailyRate                          1470 non-null   int64
#  2   DistanceFromHome                   1470 non-null   int64
#  3   Education                          1470 non-null   int64
#  4   EmployeeCount                      1470 non-null   int64
#  5   EmployeeNumber                     1470 non-null   int64
# ...

# %%
df_final3 = df_final2.drop(['Attrition_No'], axis = 1)
df_final3
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>DailyRate</th>
#       <th>DistanceFromHome</th>
#       <th>Education</th>
#       <th>EmployeeCount</th>
#       <th>EmployeeNumber</th>
#       <th>EnvironmentSatisfaction</th>
#       <th>HourlyRate</th>
#       <th>JobInvolvement</th>
#       <th>JobLevel</th>
#       <th>JobSatisfaction</th>
#       <th>MonthlyIncome</th>
#       <th>NumCompaniesWorked</th>
#       <th>PercentSalaryHike</th>
#       <th>StandardHours</th>
#       <th>StockOptionLevel</th>
#       <th>TotalWorkingYears</th>
#       <th>TrainingTimesLastYear</th>
#       <th>WorkLifeBalance</th>
# ...

# %%
X = df_final3.drop(['Attrition_Yes'], axis = 1)
y = df_final3['Attrition_Yes']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from sklearn import model_selection
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.25, stratify = y, random_state=1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Build a LOGREG model

# %%
from sklearn.linear_model import LogisticRegression

# classifier_logistic = LogisticRegression() 
# classifier_logistic.fit(X_train, y_train)
# logreg_pred = classifier_logistic.predict(X_test)
# classifier_logistic.score(X_test, y_test)

classifier_logreg = LogisticRegression(random_state=1)
classifier_logreg.fit(X_train, y_train)
logreg_pred = classifier_logreg.predict(X_test)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2021/10/25 17:07:42 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID &#39;6d4dbbb6e3f9420c8c66d8bf2638e1c1&#39;, which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# </div>

# %%
# BASELINE MODEL AUC-ROC
from sklearn.metrics import plot_roc_curve

plt.plot(plot_roc_curve(classifier_logreg, X_test, y_test))
plt.title("AUC_plot_base")
plt.savefig("AUC_plot_base.png")
mlflow.log_artifact("AUC_plot_base.png")

# %%
AUC_baseline = 0.76
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# BASELINE MODEL CONFUSION MATRIX

from sklearn.metrics import plot_confusion_matrix

plt.plot(plot_confusion_matrix(classifier_logreg, X_test, y_test))
plt.title("confusion_matrix_base")
plt.savefig("confusion_matrix_base.png")
mlflow.log_artifact("confusion_matrix_base.png")

# %%
# BASELINE MODEL PERFORMANCE

from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

accuracy_baseline = classifier_logreg.score(X_test, y_test)
precision_baseline = precision_score(y_test, logreg_pred)
recall_baseline = recall_score(y_test, logreg_pred)
f1_baseline = f1_score(y_test, logreg_pred)

print("Accuracy: ", accuracy_baseline)
print("Precision: ", precision_baseline)
print("Recall: ", recall_baseline)
print("F1: ", f1_baseline)
print("AUC: ", AUC_baseline)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Accuracy:  0.8532608695652174
# Precision:  0.6470588235294118
# Recall:  0.1864406779661017
# F1:  0.2894736842105263
# AUC:  0.76
# </div>

# %%
# LOG THE BASELINE PERFORMANCE
with mlflow.start_run():
    
    mlflow.sklearn.log_model(classifier_logreg, "base_classifier_logreg") 
        
    mlflow.log_metric("Accuracy_base", accuracy_baseline)
    mlflow.log_metric("Precision_base", precision_baseline)
    mlflow.log_metric("Recall_base", recall_baseline)
    mlflow.log_metric("F1_base", f1_baseline)
    mlflow.log_metric("AUC_base", AUC_baseline)
    
    savetxt('predictions_base.csv', RF_pred, delimiter=',')
    mlflow.log_artifact("predictions_base.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# NEW DATA

# %%
# Read from Spark

df_final = spark.read.format("csv").load("dbfs:/FileStore/shared_uploads/mucongl@uchicago.edu/final.csv", header = "True")
display(df_final)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_final_pd = df_final.toPandas()
df_final_pd.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>Attrition</th>
#       <th>BusinessTravel</th>
#       <th>DailyRate</th>
#       <th>Department</th>
#       <th>DistanceFromHome</th>
#       <th>Education</th>
#       <th>EducationField</th>
#       <th>EmployeeCount</th>
#       <th>EmployeeNumber</th>
#       <th>EnvironmentSatisfaction</th>
#       <th>Gender</th>
#       <th>HourlyRate</th>
#       <th>JobInvolvement</th>
#       <th>JobLevel</th>
#       <th>JobRole</th>
#       <th>JobSatisfaction</th>
#       <th>MaritalStatus</th>
#       <th>MonthlyIncome</th>
#       <th>MonthlyRate</th>
#       <th>NumCompaniesWorked</th>
# ...

# %%
df_final_pd.info()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &#39;pandas.core.frame.DataFrame&#39;&gt;
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   object
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   object
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   object
#  6   Education                 1470 non-null   object
# ...

# %%
df_final_dum = pd.get_dummies(df_final_pd[['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime']])
df_final_dum.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Attrition_No</th>
#       <th>Attrition_Yes</th>
#       <th>BusinessTravel_Non-Travel</th>
#       <th>BusinessTravel_Travel_Frequently</th>
#       <th>BusinessTravel_Travel_Rarely</th>
#       <th>Department_Human Resources</th>
#       <th>Department_Research &amp; Development</th>
#       <th>Department_Sales</th>
#       <th>EducationField_Human Resources</th>
#       <th>EducationField_Life Sciences</th>
#       <th>EducationField_Marketing</th>
#       <th>EducationField_Medical</th>
#       <th>EducationField_Other</th>
#       <th>EducationField_Technical Degree</th>
#       <th>Gender_Female</th>
# ...

# %%
df_final_pd.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>Attrition</th>
#       <th>BusinessTravel</th>
#       <th>DailyRate</th>
#       <th>Department</th>
#       <th>DistanceFromHome</th>
#       <th>Education</th>
#       <th>EducationField</th>
#       <th>EmployeeCount</th>
#       <th>EmployeeNumber</th>
#       <th>EnvironmentSatisfaction</th>
#       <th>Gender</th>
#       <th>HourlyRate</th>
#       <th>JobInvolvement</th>
#       <th>JobLevel</th>
#       <th>JobRole</th>
#       <th>JobSatisfaction</th>
#       <th>MaritalStatus</th>
#       <th>MonthlyIncome</th>
#       <th>MonthlyRate</th>
#       <th>NumCompaniesWorked</th>
# ...

# %%
df_final_pd.drop(columns = ['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime'], axis = 1, inplace = True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_final_pd.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>DailyRate</th>
#       <th>DistanceFromHome</th>
#       <th>Education</th>
#       <th>EmployeeCount</th>
#       <th>EmployeeNumber</th>
#       <th>EnvironmentSatisfaction</th>
#       <th>HourlyRate</th>
#       <th>JobInvolvement</th>
#       <th>JobLevel</th>
#       <th>JobSatisfaction</th>
#       <th>MonthlyIncome</th>
#       <th>MonthlyRate</th>
#       <th>NumCompaniesWorked</th>
#       <th>PercentSalaryHike</th>
#       <th>PerformanceRating</th>
#       <th>RelationshipSatisfaction</th>
#       <th>StandardHours</th>
#       <th>StockOptionLevel</th>
# ...

# %%
df_final_v2 = pd.concat([df_final_pd,df_final_dum], axis = 1)
df_final_v2.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>DailyRate</th>
#       <th>DistanceFromHome</th>
#       <th>Education</th>
#       <th>EmployeeCount</th>
#       <th>EmployeeNumber</th>
#       <th>EnvironmentSatisfaction</th>
#       <th>HourlyRate</th>
#       <th>JobInvolvement</th>
#       <th>JobLevel</th>
#       <th>JobSatisfaction</th>
#       <th>MonthlyIncome</th>
#       <th>MonthlyRate</th>
#       <th>NumCompaniesWorked</th>
#       <th>PercentSalaryHike</th>
#       <th>PerformanceRating</th>
#       <th>RelationshipSatisfaction</th>
#       <th>StandardHours</th>
#       <th>StockOptionLevel</th>
# ...

# %%
df_final_v2_2 = df_final_v2.astype(int)
df_final_v2_2.info()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &#39;pandas.core.frame.DataFrame&#39;&gt;
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 57 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                1470 non-null   int64
#  1   DailyRate                          1470 non-null   int64
#  2   DistanceFromHome                   1470 non-null   int64
#  3   Education                          1470 non-null   int64
#  4   EmployeeCount                      1470 non-null   int64
#  5   EmployeeNumber                     1470 non-null   int64
# ...

# %%
X = df_final_v2_2.drop(['Attrition_Yes','Attrition_No'], axis = 1)
y = df_final_v2_2['Attrition_Yes']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from sklearn import model_selection
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.25, stratify = y, random_state=1)

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# RandomizedSearchCV for RANDOM FOREST MODEL

# %%
from sklearn.model_selection import RandomizedSearchCV
from pprint import pprint

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1000, num = 10)]

# Number of features to consider at every split
max_features = ['auto', 'sqrt', 10]

# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 50, num = 10)]
max_depth.append(None)

# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]

# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]

# Method of selecting samples for training each tree
bootstrap = [True, False]

# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

pprint(random_grid)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&#39;bootstrap&#39;: [True, False],
#  &#39;max_depth&#39;: [5, 10, 15, 20, 25, 30, 35, 40, 45, 50, None],
#  &#39;max_features&#39;: [&#39;auto&#39;, &#39;sqrt&#39;, 10],
#  &#39;min_samples_leaf&#39;: [1, 2, 4],
#  &#39;min_samples_split&#39;: [2, 5, 10],
#  &#39;n_estimators&#39;: [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]}
# </div>

# %%
# Use the random grid to search for best hyperparameters
from sklearn.ensemble import RandomForestClassifier

# First create the base model to tune
rf = RandomForestClassifier(random_state=1)

# Random search of parameters, using 5 fold cross validation, 
# Search across 50 different combinations, and use all available cores
rf_random = RandomizedSearchCV(estimator = rf, 
                               param_distributions = random_grid, 
                               n_iter = 50, cv = 5, verbose=2, random_state=1, n_jobs = -1)

# Fit the random search model
rf_random.fit(X_train, y_train)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2021/10/25 17:29:53 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID &#39;0f1483949e0647c6942ee79ddcfd6deb&#39;, which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2021/10/25 17:29:53 WARNING mlflow.utils: Truncated the value of the key `estimator`. Truncated value: `RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion=&#39;gini&#39;, max_depth=None, max_features=&#39;auto&#39;,
#                        max_leaf_nodes=None, max_samples=None,
# ...

# %%
# View the best parameters from fitting the Random Search

rf_random_pred = rf_random.predict(X_test)
rf_random.best_params_
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[106]: {&#39;n_estimators&#39;: 100,
#  &#39;min_samples_split&#39;: 10,
#  &#39;min_samples_leaf&#39;: 1,
#  &#39;max_features&#39;: 10,
#  &#39;max_depth&#39;: 20,
#  &#39;bootstrap&#39;: False}</div>

# %%
# Random Forest baseline MODEL AUC-ROC
from sklearn.metrics import plot_roc_curve

plt.plot(plot_roc_curve(rf_random, X_test, y_test))
plt.title("rf_AUC_plot_base")
plt.savefig("rf_AUC_plot_base.png")
mlflow.log_artifact("rf_AUC_plot_base.png")

# %%
rf_random_AUC_baseline = 0.83
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Random Forest baseline MODEL CONFUSION MATRIX

from sklearn.metrics import plot_confusion_matrix

plt.plot(plot_confusion_matrix(rf_random, X_test, y_test))
plt.title("rf_confusion_matrix_base")
plt.savefig("rf_confusion_matrix_base.png")
mlflow.log_artifact("rf_confusion_matrix_base.png")

# %%
# BASELINE MODEL PERFORMANCE

from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score

rf_random_accuracy_baseline = rf_random.score(X_test, y_test)
rf_random_precision_baseline = precision_score(y_test, rf_random_pred)
rf_random_recall_baseline = recall_score(y_test, rf_random_pred)
rf_random_f1_baseline = f1_score(y_test, rf_random_pred)

print("rf_random_Accuracy: ", rf_random_accuracy_baseline)
print("rf_random_Precision: ", rf_random_precision_baseline)
print("rf_random_Recall: ", rf_random_recall_baseline)
print("rf_random_F1: ", rf_random_f1_baseline)
print("rf_random_AUC: ", rf_random_AUC_baseline)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">rf_random_Accuracy:  0.8668478260869565
# rf_random_Precision:  0.6923076923076923
# rf_random_Recall:  0.3050847457627119
# rf_random_F1:  0.4235294117647059
# rf_random_AUC:  0.83
# </div>

# %%
# LOG THE BASELINE PERFORMANCE
with mlflow.start_run():
    
    mlflow.sklearn.log_model(rf_random, "rf_random-model") 
        
    mlflow.log_metric("rf_random_Accuracy", rf_random_accuracy_baseline)
    mlflow.log_metric("rf_random_Precision", rf_random_precision_baseline)
    mlflow.log_metric("rf_random_Recall", rf_random_recall_baseline)
    mlflow.log_metric("rf_random_F1", rf_random_f1_baseline)
    mlflow.log_metric("rf_random_AUC", rf_random_AUC_baseline)
    
    savetxt('rf_random_predictions.csv', rf_random_pred, delimiter=',')
    mlflow.log_artifact("rf_random_predictions.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# RF GRID SEARCH & MLFLOW LOGGING

# %%
rf_random.best_params_
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[111]: {&#39;n_estimators&#39;: 100,
#  &#39;min_samples_split&#39;: 10,
#  &#39;min_samples_leaf&#39;: 1,
#  &#39;max_features&#39;: 10,
#  &#39;max_depth&#39;: 20,
#  &#39;bootstrap&#39;: False}</div>

# %%
# Enable autolog()
# mlflow.sklearn.autolog() requires mlflow 1.11.0 or above.
mlflow.sklearn.autolog()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# GRID 1 - simulate rf_random

with mlflow.start_run():
  
  # Set the model parameters. 
    n_estimators = 100
    max_depth = 20
    max_features = 10
  
  # Create and train model.
    rf = RandomForestClassifier(n_estimators = n_estimators, max_depth = max_depth, max_features = max_features, random_state = 1)
    rf.fit(X_train, y_train)
  
  # Use the model to make predictions on the test dataset.
    predictions = rf.predict(X_test)
  
  # Log the model parameters used for this run.
    mlflow.log_param("num_trees", n_estimators)
    mlflow.log_param("maxdepth", max_depth)
    mlflow.log_param("max_feat", max_features)
  

  # Log the model created by this run.
    mlflow.sklearn.log_model(rf, "rf_grid-model")
  
  # Save the table of predicted values
    savetxt('rf_grid_predictions.csv', predictions, delimiter=',')
  
  # Log the saved table as an artifact
    mlflow.log_artifact("rf_grid_predictions.csv")
  
  # Compute the metrics
    rf_grid_accuracy = rf.score(X_test, y_test)
    rf_grid_precision = precision_score(y_test, predictions)
    rf_grid_recall = recall_score(y_test, predictions)
    rf_grid_f1 = f1_score(y_test, predictions)
    rf_grid_roc_auc = roc_auc_score(y_test, predictions)

  # Log the metrics
    mlflow.log_metric("rf_grid_Accuracy", rf_grid_accuracy)
    mlflow.log_metric("rf_grid_Precision", rf_grid_precision)
    mlflow.log_metric("rf_grid_Recall", rf_grid_recall)
    mlflow.log_metric("rf_grid_F1", rf_grid_f1)
    mlflow.log_metric("rf_grid_AUC", rf_grid_roc_auc)
 
  # Save the plot and log it as an artifact
    plt.savefig("residuals_plot.png")
    mlflow.log_artifact("residuals_plot.png") 
    
  # ROC-AUC curve plot & log
    plt.plot(plot_roc_curve(rf, X_test, y_test))
    plt.title("rf_AUC_plot")
    plt.savefig("rf_AUC_plot.png")
    mlflow.log_artifact("rf_AUC_plot.png") 
    
  # Confusion matrix & log
    plt.plot(plot_confusion_matrix(rf, X_test, y_test))
    plt.title("rf_confusion_matrix")
    plt.savefig("rf_confusion_matrix.png")
    mlflow.log_artifact("rf_confusion_matrix.png")

# %%
# GRID 2 - simulate rf_random

with mlflow.start_run():
  
  # Set the model parameters. 
    n_estimators = 100
    max_depth = 30
    max_features = 20
  
  # Create and train model.
    rf = RandomForestClassifier(n_estimators = n_estimators, max_depth = max_depth, max_features = max_features, random_state = 1)
    rf.fit(X_train, y_train)
  
  # Use the model to make predictions on the test dataset.
    predictions = rf.predict(X_test)
  
  # Log the model parameters used for this run.
    mlflow.log_param("num_trees", n_estimators)
    mlflow.log_param("maxdepth", max_depth)
    mlflow.log_param("max_feat", max_features)
  

  # Log the model created by this run.
    mlflow.sklearn.log_model(rf, "rf_grid-model")
  
  # Save the table of predicted values
    savetxt('rf_grid_predictions.csv', predictions, delimiter=',')
  
  # Log the saved table as an artifact
    mlflow.log_artifact("rf_grid_predictions.csv")
  
  # Compute the metrics
    rf_grid_accuracy = rf.score(X_test, y_test)
    rf_grid_precision = precision_score(y_test, predictions)
    rf_grid_recall = recall_score(y_test, predictions)
    rf_grid_f1 = f1_score(y_test, predictions)
    rf_grid_roc_auc = roc_auc_score(y_test, predictions)

  # Log the metrics
    mlflow.log_metric("rf_grid_Accuracy", rf_grid_accuracy)
    mlflow.log_metric("rf_grid_Precision", rf_grid_precision)
    mlflow.log_metric("rf_grid_Recall", rf_grid_recall)
    mlflow.log_metric("rf_grid_F1", rf_grid_f1)
    mlflow.log_metric("rf_grid_AUC", rf_grid_roc_auc)
 
  # Save the plot and log it as an artifact
    plt.savefig("residuals_plot.png")
    mlflow.log_artifact("residuals_plot.png") 
    
  # ROC-AUC curve plot & log
    plt.plot(plot_roc_curve(rf, X_test, y_test))
    plt.title("rf_AUC_plot")
    plt.savefig("rf_AUC_plot.png")
    mlflow.log_artifact("rf_AUC_plot.png") 
    
  # Confusion matrix & log
    plt.plot(plot_confusion_matrix(rf, X_test, y_test))
    plt.title("rf_confusion_matrix")
    plt.savefig("rf_confusion_matrix.png")
    mlflow.log_artifact("rf_confusion_matrix.png")

# %%
# GRID 3 - simulate rf_random

with mlflow.start_run():
  # Set the model parameters. 
    n_estimators = 300
    max_depth = 10
    max_features = 20
  
  # Create and train model.
    rf = RandomForestClassifier(n_estimators = n_estimators, max_depth = max_depth, max_features = max_features, random_state = 1)
    rf.fit(X_train, y_train)
  
  # Use the model to make predictions on the test dataset.
    predictions = rf.predict(X_test)
  
  # Log the model parameters used for this run.
    mlflow.log_param("num_trees", n_estimators)
    mlflow.log_param("maxdepth", max_depth)
    mlflow.log_param("max_feat", max_features)

  # Log the model created by this run.
    mlflow.sklearn.log_model(rf, "rf_grid-model")
  
  # Save the table of predicted values
    savetxt('rf_grid_predictions.csv', predictions, delimiter=',')
  
  # Log the saved table as an artifact
    mlflow.log_artifact("rf_grid_predictions.csv")
  
  # Compute the metrics
    rf_grid_accuracy = rf.score(X_test, y_test)
    rf_grid_precision = precision_score(y_test, predictions)
    rf_grid_recall = recall_score(y_test, predictions)
    rf_grid_f1 = f1_score(y_test, predictions)
    rf_grid_roc_auc = roc_auc_score(y_test, predictions)

  # Log the metrics
    mlflow.log_metric("rf_grid_Accuracy", rf_grid_accuracy)
    mlflow.log_metric("rf_grid_Precision", rf_grid_precision)
    mlflow.log_metric("rf_grid_Recall", rf_grid_recall)
    mlflow.log_metric("rf_grid_F1", rf_grid_f1)
    mlflow.log_metric("rf_grid_AUC", rf_grid_roc_auc)
 
  # Save the plot and log it as an artifact
    plt.savefig("residuals_plot.png")
    mlflow.log_artifact("residuals_plot.png") 
    
  # ROC-AUC curve plot & log
    plt.plot(plot_roc_curve(rf, X_test, y_test))
    plt.title("rf_AUC_plot")
    plt.savefig("rf_AUC_plot.png")
    mlflow.log_artifact("rf_AUC_plot.png") 
    
  # Confusion matrix & log
    plt.plot(plot_confusion_matrix(rf, X_test, y_test))
    plt.title("rf_confusion_matrix")
    plt.savefig("rf_confusion_matrix.png")
    mlflow.log_artifact("rf_confusion_matrix.png")
